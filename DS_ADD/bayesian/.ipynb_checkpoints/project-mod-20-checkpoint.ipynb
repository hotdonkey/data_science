# %%
import arviz as az
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import pymc3 as pm


import seaborn as sns

# %%
raw_data = pd.read_csv(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",
    header=None,
    names=[
        "age",
        "workclass",
        "fnlwgt",
        "education-categorical",
        "educ",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "captial-gain",
        "capital-loss",
        "hours",
        "native-country",
        "income",
    ],
)

# %%
raw_data.head(10)
# Out:
#    age          workclass  fnlwgt education-categorical  educ  \
# 0   39          State-gov   77516             Bachelors    13
# 1   50   Self-emp-not-inc   83311             Bachelors    13
# 2   38            Private  215646               HS-grad     9
# 3   53            Private  234721                  11th     7
# 4   28            Private  338409             Bachelors    13
# 5   37            Private  284582               Masters    14
# 6   49            Private  160187                   9th     5
# 7   52   Self-emp-not-inc  209642               HS-grad     9
# 8   31            Private   45781               Masters    14
# 9   42            Private  159449             Bachelors    13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  captial-gain  capital-loss  hours  native-country  income
# 0     Male          2174             0     40   United-States   <=50K
# 1     Male             0             0     13   United-States   <=50K
# 2     Male             0             0     40   United-States   <=50K
# 3     Male             0             0     40   United-States   <=50K
# 4   Female             0             0     40            Cuba   <=50K
# 5   Female             0             0     40   United-States   <=50K
# 6   Female             0             0     16         Jamaica   <=50K
# 7     Male             0             0     45   United-States    >50K
# 8   Female         14084             0     50   United-States    >50K
# 9     Male          5178             0     40   United-States    >50K

# %% [markdown]
# ## Подготовим данные

# %%
data = raw_data[~pd.isnull(raw_data["income"])]

# %%
data[data["native-country"] == " United-States"].sample(5)
# Out:
#        age   workclass  fnlwgt education-categorical  educ  marital-status  \
# 5090    44     Private  275094               1st-4th     2   Never-married
# 29276   35     Private  397307               Masters    14   Never-married
# 18980   53     Private  149650               HS-grad     9   Never-married
# 22725   23     Private  216811               HS-grad     9   Never-married
# 22203   18   Local-gov  152182                  10th     6   Never-married
#
#              occupation    relationship    race      sex  captial-gain  \
# 5090      Other-service       Own-child   White     Male             0
# 29276   Exec-managerial   Not-in-family   White   Female             0
# 18980             Sales   Not-in-family   White     Male             0
# 22725      Adm-clerical       Own-child   White   Female             0
# 22203   Protective-serv       Own-child   White   Female             0
#
#        capital-loss  hours  native-country  income
# 5090              0     10   United-States   <=50K
# 29276             0     55   United-States   <=50K
# 18980          2559     48   United-States    >50K
# 22725             0     16   United-States   <=50K
# 22203             0      6   United-States   <=50K

# %%
income = 1 * (data["income"] == " >50K")

# %%
data = data[["age", "educ", "hours","marital-status"]]

# Scale age by 10, it helps with model convergence.
data["age"] = data["age"] / 10.0
data["age2"] = np.square(data["age"])
data["income"] = income

income.value_counts()
# Out:
# income
# 0    24720
# 1     7841
# Name: count, dtype: int64

# %%
def replace_marital(marital):
    if 'married' in marital.lower():
        return 4
    elif 'single' in marital.lower():
        return 3
    elif 'divorced' in marital.lower():
        return 2
    elif 'unknown' in marital.lower():
        return 1
    
data['marital'] = data["marital-status"].apply(lambda x: replace_marital(x))

data['marital'].fillna(1, inplace=True)

# %%
with pm.Model() as logistic_model:
    pm.glm.GLM.from_formula('income ~ age + age2 + marital + educ ', data, family = pm.glm.families.Binomial())
    trace = pm.sample(1000)
    
az.plot_trace(trace);
# Out:
# The glm module is deprecated and will be removed in version 4.0
# We recommend to instead use Bambi https://bambinos.github.io/bambi/
# /Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/deprecat/classic.py:215: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   return wrapped_(*args_, **kwargs_)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [educ, marital, age2, age, Intercept]
# Traceback (most recent call last):
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/ffi.py", line 136, in __getattr__
#     return self._fntab[name]
# KeyError: 'LLVMPY_AddSymbol'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/ffi.py", line 117, in _load_lib
#     self._lib_handle = ctypes.CDLL(str(lib_path))
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py", line 366, in __init__
#     self._handle = _dlopen(self._name, mode)
# OSError: dlopen(/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/libllvmlite.dylib, 0x0006): Library not loaded: @rpath/libz.1.dylib
#   Referenced from: <F70ADCC0-A388-302B-A80A-072EB26AC88A> /Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/libllvmlite.dylib
#   Reason: tried: '/libz.1.dylib' (no such file)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/forkserver.py", line 274, in main
#     code = _serve_one(child_r, fds,
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/forkserver.py", line 313, in _serve_one
#     code = spawn._main(child_r, parent_sentinel)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/__init__.py", line 115, in <module>
#     from pymc3 import gp, ode, sampling
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/gp/__init__.py", line 16, in <module>
#     from pymc3.gp.gp import TP, Latent, LatentKron, Marginal, MarginalKron, MarginalSparse
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/gp/gp.py", line 25, in <module>
#     from pymc3.distributions import draw_values
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/distributions/__init__.py", line 15, in <module>
#     from pymc3.distributions import shape_utils, timeseries, transforms
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/distributions/timeseries.py", line 21, in <module>
#     from pymc3.distributions import distribution, multivariate
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/distributions/distribution.py", line 45, in <module>
#     from pymc3.model import (
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/model.py", line 38, in <module>
#     from pymc3.blocking import ArrayOrdering, DictToArrayBijection
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/blocking.py", line 25, in <module>
#     from pymc3.util import get_var_name
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/pymc3/util.py", line 21, in <module>
#     import arviz
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/__init__.py", line 33, in <module>
#     from .plots import *
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/plots/__init__.py", line 2, in <module>
#     from .autocorrplot import plot_autocorr
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/plots/autocorrplot.py", line 7, in <module>
#     from .plot_utils import default_grid, filter_plotters_list, get_plotting_function
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/plots/plot_utils.py", line 15, in <module>
#     from ..stats.density_utils import kde
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/stats/__init__.py", line 4, in <module>
#     from .diagnostics import *
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/stats/diagnostics.py", line 13, in <module>
#     from .stats_utils import _circular_standard_deviation, _sqrt
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/stats/stats_utils.py", line 538, in <module>
#     def _sqrt(a_a, b_b):
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/utils.py", line 309, in conditional_vect
#     return wrapper(function)
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/arviz/utils.py", line 302, in wrapper
#     numba = importlib.import_module("numba")
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/numba/__init__.py", line 70, in <module>
#     from numba.core import config
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/numba/core/config.py", line 17, in <module>
#     import llvmlite.binding as ll
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/__init__.py", line 4, in <module>
#     from .dylib import *
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/dylib.py", line 36, in <module>
#     ffi.lib.LLVMPY_AddSymbol.argtypes = [
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/ffi.py", line 139, in __getattr__
#     cfn = getattr(self._lib, name)
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/ffi.py", line 131, in _lib
#     self._load_lib()
#   File "/Users/kirillkuznecov/Library/Python/3.9/lib/python/site-packages/llvmlite/binding/ffi.py", line 125, in _load_lib
#     raise OSError("Could not find/load shared object file") from e
# OSError: Could not find/load shared object file
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 with pm.Model() as logistic_model:
#       2     pm.glm.GLM.from_formula('income ~ age + age2 + marital + educ ', data, family = pm.glm.families.Binomial())
# ----> 3     trace = pm.sample(1000)
#       5 az.plot_trace(trace);
#
# File ~/Library/Python/3.9/lib/python/site-packages/deprecat/classic.py:215, in deprecat.<locals>.wrapper_function(wrapped_, instance_, args_, kwargs_)
#     213         else:
#     214             warnings.warn(message, category=category, stacklevel=_routine_stacklevel)
# --> 215 return wrapped_(*args_, **kwargs_)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymc3/sampling.py:575, in sample(draws, step, init, n_init, initvals, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, callback, jitter_max_retries, start, return_inferencedata, idata_kwargs, mp_ctx, pickle_backend, **kwargs)
#     573 _print_step_hierarchy(step)
#     574 try:
# --> 575     trace = _mp_sample(**sample_args, **parallel_args)
#     576 except pickle.PickleError:
#     577     _log.warning("Could not pickle model, sampling singlethreaded.")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymc3/sampling.py:1480, in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, callback, discard_tuned_samples, mp_ctx, pickle_backend, **kwargs)
#    1477         strace.setup(draws + tune, idx + chain)
#    1478     traces.append(strace)
# -> 1480 sampler = ps.ParallelSampler(
#    1481     draws,
#    1482     tune,
#    1483     chains,
#    1484     cores,
#    1485     random_seed,
#    1486     start,
#    1487     step,
#    1488     chain,
#    1489     progressbar,
#    1490     mp_ctx=mp_ctx,
#    1491     pickle_backend=pickle_backend,
#    1492 )
#    1493 try:
#    1494     try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymc3/parallel_sampling.py:431, in ParallelSampler.__init__(self, draws, tune, chains, cores, seeds, start_points, step_method, start_chain_num, progressbar, mp_ctx, pickle_backend)
#     428             raise ValueError("dill must be installed for pickle_backend='dill'.")
#     429         step_method_pickled = dill.dumps(step_method, protocol=-1)
# --> 431 self._samplers = [
#     432     ProcessAdapter(
#     433         draws,
#     434         tune,
#     435         step_method,
#     436         step_method_pickled,
#     437         chain + start_chain_num,
#     438         seed,
#     439         start,
#     440         mp_ctx,
#     441         pickle_backend,
#     442     )
#     443     for chain, seed, start in zip(range(chains), seeds, start_points)
#     444 ]
#     446 self._inactive = self._samplers.copy()
#     447 self._finished = []
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymc3/parallel_sampling.py:432, in <listcomp>(.0)
#     428             raise ValueError("dill must be installed for pickle_backend='dill'.")
#     429         step_method_pickled = dill.dumps(step_method, protocol=-1)
#     431 self._samplers = [
# --> 432     ProcessAdapter(
#     433         draws,
#     434         tune,
#     435         step_method,
#     436         step_method_pickled,
#     437         chain + start_chain_num,
#     438         seed,
#     439         start,
#     440         mp_ctx,
#     441         pickle_backend,
#     442     )
#     443     for chain, seed, start in zip(range(chains), seeds, start_points)
#     444 ]
#     446 self._inactive = self._samplers.copy()
#     447 self._finished = []
#
# File ~/Library/Python/3.9/lib/python/site-packages/pymc3/parallel_sampling.py:292, in ProcessAdapter.__init__(self, draws, tune, step_method, step_method_pickled, chain, seed, start, mp_ctx, pickle_backend)
#     274     step_method_send = step_method
#     276 self._process = mp_ctx.Process(
#     277     daemon=True,
#     278     name=process_name,
#    (...)
#     290     ),
#     291 )
# --> 292 self._process.start()
#     293 # Close the remote pipe, so that we get notified if the other
#     294 # end is closed.
#     295 remote_conn.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/context.py:291, in ForkServerProcess._Popen(process_obj)
#     288 @staticmethod
#     289 def _Popen(process_obj):
#     290     from .popen_forkserver import Popen
# --> 291     return Popen(process_obj)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/popen_forkserver.py:35, in Popen.__init__(self, process_obj)
#      33 def __init__(self, process_obj):
#      34     self._fds = []
# ---> 35     super().__init__(process_obj)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/popen_forkserver.py:58, in Popen._launch(self, process_obj)
#      55 self.finalizer = util.Finalize(self, util.close_fds,
#      56                                (_parent_w, self.sentinel))
#      57 with open(w, 'wb', closefd=True) as f:
# ---> 58     f.write(buf.getbuffer())
#      59 self.pid = forkserver.read_signed(self.sentinel)
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
plt.figure(figsize=(9, 7))
sns.jointplot(trace["age"], trace["educ"], kind="hex", color="#4CB391")
plt.xlabel("beta_age")
plt.ylabel("beta_educ");
# Out:
# /Users/y.mochalova/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Итак, влияют ли возраст и образование на вероятность заработать больше, чем 50К?
#
# Чтобы ответить на этот вопрос мы покажем, что вероятность получить больше 50K меняется с возрастом и семейным положением для нескольких уровней образования.
#
# PyMC3 дает нам удобный способ построить апостериорное прогнозирующее распределение. Нам нужно передать функции линейную модель и набор точек для оценки. Мы перейдем к трем различным линейным моделям: одна с образованием == 12 (законченная средняя школа), одна с образованием == 16 (окончание бакалавриата) и одна с образованием == 19 (трехгодичная аспирантура).

# %%
def lm_full(trace, age, education, marital):
    shape = np.broadcast(age, education, marital).shape
    x_norm = np.asarray([np.broadcast_to(x, shape) for x in [age/10., education, marital]])
    
    return 1 / (1 + np.exp(-(trace['Intercept'] + 
                             trace['age']*x_norm[0] + 
                             trace['age2']*(x_norm[0]**2) +
                             trace['educ']*x_norm[1] +
                             trace['marital']*x_norm[2])))

lm = lambda x, samples: lm_full(samples, x, 12., 4.)
lm2 = lambda x, samples: lm_full(samples, x, 16., 4.)
lm3 = lambda x, samples: lm_full(samples, x, 19., 4.)


pm.plot_posterior_predictive_glm(trace, eval=np.linspace(25,75,1000), lm=lm, samples=100, color='blue', alpha=.8)
pm.plot_posterior_predictive_glm(trace, eval=np.linspace(25,75,1000), lm=lm2, samples=100, color='green', alpha=.8)
pm.plot_posterior_predictive_glm(trace, eval=np.linspace(25,75,1000), lm=lm3, samples=100, color='red', alpha=.8)

blue_line = mlines.Line2D(["lm"], [], color="b", label="High School Education")
green_line = mlines.Line2D(["lm2"], [], color="g", label="Bachelors")
red_line = mlines.Line2D(["lm3"], [], color="r", label="Grad School")
plt.legend(handles=[blue_line, green_line, red_line], loc="lower right")
plt.ylabel("P(Income > $50K)")
plt.xlabel("Age")
plt.show();
# Out:
# /Users/y.mochalova/opt/anaconda3/lib/python3.8/site-packages/pymc3/plots/posteriorplot.py:59: DeprecationWarning: The `plot_posterior_predictive_glm` function will migrate to Arviz in a future release.
# Keep up to date with `ArviZ <https://arviz-devs.github.io/arviz/>`_ for future updates.
#   warnings.warn(
# /Users/y.mochalova/opt/anaconda3/lib/python3.8/site-packages/pymc3/plots/posteriorplot.py:59: DeprecationWarning: The `plot_posterior_predictive_glm` function will migrate to Arviz in a future release.
# Keep up to date with `ArviZ <https://arviz-devs.github.io/arviz/>`_ for future updates.
#   warnings.warn(
# /Users/y.mochalova/opt/anaconda3/lib/python3.8/site-packages/pymc3/plots/posteriorplot.py:59: DeprecationWarning: The `plot_posterior_predictive_glm` function will migrate to Arviz in a future release.
# Keep up to date with `ArviZ <https://arviz-devs.github.io/arviz/>`_ for future updates.
#   warnings.warn(

# %% [markdown]
# Каждая кривая показывает, насколько вероятность заработать больше, чем 50K меняется с возрастом. Красная кривая представляет 19 лет образования, зеленая кривая представляет 16 лет образования, а синяя кривая представляет 12 лет образования. Для всех трех уровней образования вероятность заработка более 50 тысяч долларов увеличивается с возрастом примерно до 60 лет, когда вероятность начинает снижаться. Обратите внимание, что каждая кривая немного размыта. Это потому, что мы фактически строим 100 различных кривых для каждого уровня образования. Каждая кривая является результатом нашего апостериорного распределения. Поскольку кривые в некоторой степени полупрозрачны, мы можем интерпретировать темные узкие участки кривой как места, где у нас низкая неопределенность, а светлые, расширенные участки кривой - как места, где у нас есть несколько более высокая неопределенность в отношении значений наших коэффициентов.

# %%
pm.summary(trace)
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /Users/y.mochalova/opt/anaconda3/lib/python3.8/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
#              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# Intercept -16.344  0.234 -16.781  -15.896      0.007    0.005    1036.0
# age         3.702  0.087   3.544    3.869      0.003    0.002    1159.0
# age2       -0.353  0.010  -0.371   -0.335      0.000    0.000    1181.0
# marital     0.805  0.021   0.766    0.846      0.000    0.000    1876.0
# educ        0.335  0.007   0.324    0.348      0.000    0.000    2700.0
#
#            ess_tail  r_hat
# Intercept    1560.0    1.0
# age          1587.0    1.0
# age2         1570.0    1.0
# marital      2291.0    1.0
# educ         2033.0    1.0

# %% [markdown]
# ## Сравнение с логистической регрессией

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(data[['age', 'educ',  'age2', 'marital']], data['income'])
# Out:
# LogisticRegression()

# %%
lr.intercept_
# Out:
# array([-16.26445812])

# %%
pd.DataFrame(lr.coef_[0], index=['age', 'educ',  'age2', 'marital'])
# Out:
#                 0
# age      3.669533
# educ     0.335039
# age2    -0.349695
# marital  0.803746
