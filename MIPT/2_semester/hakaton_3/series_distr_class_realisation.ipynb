# %%
from datetime import timedelta
import pysrt
import pandas as pd
from typing import Dict, List, Optional, Tuple, Any

from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import os

from collections import Counter

import random
from datetime import timedelta

import subprocess
import os
from datetime import timedelta

from transformers import pipeline

from moviepy import VideoFileClip
import os

import warnings
warnings.filterwarnings("ignore")

# %%
MODEL_NAME = "handler-bird/movie_genre_multi_classification"
SAVE_DIR = "./local_model"

# Проверяем, существует ли папка и файлы модели
if not os.path.exists(SAVE_DIR) or not os.listdir(SAVE_DIR):
    print("Модель не найдена локально. Скачиваю...")
    
    # Создаем папку, если её нет
    os.makedirs(SAVE_DIR, exist_ok=True)

    # Скачиваем токенизатор и модель
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)

    # Сохраняем локально
    tokenizer.save_pretrained(SAVE_DIR)
    model.save_pretrained(SAVE_DIR)
    
    print(f"Модель успешно сохранена в {SAVE_DIR}")
else:
    print(f"Модель уже существует в {SAVE_DIR}. Пропускаем скачивание.")
# Out:
# Модель уже существует в ./local_model. Пропускаем скачивание.

# %%
LOCAL_MODEL_PATH = "./local_model"
VIDEO_DIR = "./data/vids"
#file_name = "15716_1_1"

# %%
class RecapVideoTransformer:
    """
    Класс для создания краткого обзора (recap) видео на основе анализа жанра и временных меток субтитров.

    Основные этапы работы:
    1. Загрузка субтитров.
    2. Определение жанра видео.
    3. Расчёт ключевых моментов в зависимости от жанра.
    4. Вырезание соответствующих фрагментов из видео.
    5. Склейка фрагментов в один итоговый файл.

    Атрибуты:
        file_name (str): Имя видеофайла без расширения.
        df (pd.DataFrame): Датафрейм с субтитрами (временные метки и текст).
        genre (str): Обнаруженный жанр видео.
        total_length (int): Длительность итогового рекэпа в секундах.
        recap (dict): Словарь с ключевыми моментами и временными рамками.
        clips_times (list): Список кортежей (start, end) для вырезания клипов.
        input_video_path (str): Путь к исходному видеофайлу.
        output_video_path (str): Путь к выходному видеофайлу.
        list_file (str): Путь к временному файлу списка клипов для FFmpeg.
    """

    # Словарь временных зон для разных жанров
    genre_dict = \
        {
            "drama": {
                "setup_conflict": {
                    "description": "Установление основного конфликта",
                    "start_percent": 5.0,
                    "end_percent": 15.0
                },
                "character_development": {
                    "description": "Эмоциональное развитие персонажа",
                    "start_percent": 20.0,
                    "end_percent": 40.0
                },
                "plot_twist": {
                    "description": "Поворот сюжета или неожиданное развитие",
                    "start_percent": 50.0,
                    "end_percent": 60.0
                },
                "climax_confrontation": {
                    "description": "Главный конфликт между героями",
                    "start_percent": 60.0,
                    "end_percent": 75.0
                },
                "partial_resolution": {
                    "description": "Частичное разрешение, но с продолжением",
                    "start_percent": 80.0,
                    "end_percent": 90.0
                },
                "cliffhanger": {
                    "description": "Неожиданный поворот или намёк на следующую серию",
                    "start_percent": 95.0,
                    "end_percent": 100.0
                }
            },

            "crime": {
                "crime_discovery": {
                    "description": "Обнаружение преступления или загадка",
                    "start_percent": 0.0,
                    "end_percent": 10.0
                },
                "gathering_clues": {
                    "description": "Расследование, сбор улик",
                    "start_percent": 15.0,
                    "end_percent": 35.0
                },
                "false_lead": {
                    "description": "Ложный след или неправильная версия",
                    "start_percent": 35.0,
                    "end_percent": 50.0
                },
                "truth_revealed": {
                    "description": "Открытие истинного преступника или причины",
                    "start_percent": 60.0,
                    "end_percent": 75.0
                },
                "resolution": {
                    "description": "Завершение дела или арест",
                    "start_percent": 80.0,
                    "end_percent": 90.0
                },
                "emotional_ending": {
                    "description": "Реакция главных героев или намёк на будущее",
                    "start_percent": 90.0,
                    "end_percent": 100.0
                }
            },

            "fantasy": {
                "quest_announced": {
                    "description": "Объявление цели или миссии",
                    "start_percent": 0.0,
                    "end_percent": 10.0
                },
                "trials": {
                    "description": "Пройденные испытания или битвы",
                    "start_percent": 10.0,
                    "end_percent": 50.0
                },
                "betrayal_or_failure": {
                    "description": "Предательство или крупная потеря",
                    "start_percent": 50.0,
                    "end_percent": 65.0
                },
                "power_or_knowledge_gained": {
                    "description": "Герои получают силу или знание для победы",
                    "start_percent": 65.0,
                    "end_percent": 80.0
                },
                "final_battle": {
                    "description": "Финальная битва с главным злом",
                    "start_percent": 80.0,
                    "end_percent": 95.0
                },
                "new_horizon": {
                    "description": "Намёк на новое приключение или путь",
                    "start_percent": 95.0,
                    "end_percent": 100.0
                }
            },

            "comedy": {
                "funny_situation_introduced": {
                    "description": "Введение забавной ситуации",
                    "start_percent": 0.0,
                    "end_percent": 10.0
                },
                "absurdity_increases": {
                    "description": "Усиление абсурда или ошибок",
                    "start_percent": 10.0,
                    "end_percent": 30.0
                },
                "peak_of_humor": {
                    "description": "Максимальный юмор, точка кульминации",
                    "start_percent": 30.0,
                    "end_percent": 50.0
                },
                "attempt_to_fix": {
                    "description": "Попытка исправить ситуацию",
                    "start_percent": 50.0,
                    "end_percent": 70.0
                },
                "unexpected_result": {
                    "description": "Неожиданный смешной результат",
                    "start_percent": 70.0,
                    "end_percent": 90.0
                },
                "ironic_conclusion": {
                    "description": "Шутка на прощание или клиффхенгер",
                    "start_percent": 90.0,
                    "end_percent": 100.0
                }
            },

            "sci-fi": {
                "technology_introduced": {
                    "description": "Введение нового явления или технологии",
                    "start_percent": 0.0,
                    "end_percent": 10.0
                },
                "consequences_explored": {
                    "description": "Изучение последствий использования",
                    "start_percent": 10.0,
                    "end_percent": 40.0
                },
                "ethical_dilemma": {
                    "description": "Моральный выбор или риск",
                    "start_percent": 40.0,
                    "end_percent": 60.0
                },
                "crisis_occurs": {
                    "description": "Происходит кризис или угроза",
                    "start_percent": 60.0,
                    "end_percent": 80.0
                },
                "solution_found": {
                    "description": "Находится решение или новое понимание",
                    "start_percent": 80.0,
                    "end_percent": 95.0
                },
                "philosophical_note": {
                    "description": "Философский вывод или вопрос",
                    "start_percent": 95.0,
                    "end_percent": 100.0
                }
            },

            "horror": {
                "atmosphere_set": {
                    "description": "Создание атмосферы страха",
                    "start_percent": 0.0,
                    "end_percent": 10.0
                },
                "first_fear": {
                    "description": "Первый страх или сигнал опасности",
                    "start_percent": 10.0,
                    "end_percent": 25.0
                },
                "tension_builds": {
                    "description": "Наращивание напряжения",
                    "start_percent": 25.0,
                    "end_percent": 50.0
                },
                "main_horror_moment": {
                    "description": "Главный момент ужаса или жертва",
                    "start_percent": 50.0,
                    "end_percent": 70.0
                },
                "escape_or_chase": {
                    "description": "Погоня или попытка спастись",
                    "start_percent": 70.0,
                    "end_percent": 85.0
                },
                "unresolved_end": {
                    "description": "Неожиданный финал или намёк на продолжение",
                    "start_percent": 85.0,
                    "end_percent": 100.0
                }
            },
            "default": {
                "setup": {
                    "description": "Введение основного конфликта или ситуации",
                    "start_percent": 5.0,
                    "end_percent": 15.0
                },
                "development": {
                    "description": "Развитие событий, углубление в сюжет",
                    "start_percent": 20.0,
                    "end_percent": 45.0
                },
                "plot_twist": {
                    "description": "Неожиданный поворот или осложнение",
                    "start_percent": 50.0,
                    "end_percent": 65.0
                },
                "climax": {
                    "description": "Кульминационный момент действия",
                    "start_percent": 70.0,
                    "end_percent": 85.0
                },
                "cliffhanger": {
                    "description": "Финальный намёк на следующую серию",
                    "start_percent": 90.0,
                    "end_percent": 100.0
                }
            }

        }

    # Единые ключевые моменты для всех жанров
    UNIFIED_KEY_MOMENTS = {
        "setup": {"description": "Введение основной ситуации или конфликта"},
        "development": {"description": "Развитие сюжета, углубление в историю"},
        "twist": {"description": "Неожиданный поворот или осложнение"},
        "climax": {"description": "Кульминационный момент"},
        "resolution": {"description": "Разрешение или намёк на продолжение"},
        "cliffhanger": {"description": "Финальное событие или клиффхенгер"}
    }

    def __init__(self, file_name: str):
        """
        Инициализация класса.

        Проверяет наличие необходимых файлов, определяет жанр,
        рассчитывает ключевые моменты и создаёт итоговое видео.

        Args:
            file_name (str): Имя видеофайла без расширения.
        """
        self.file_name = file_name

        # Проверяем существование файлов
        if not os.path.exists(f'./data/subtitles/{self.file_name}.srt'):
            raise FileNotFoundError(
                f"Subtitles file ./data/subtitles/{self.file_name}.srt not found")
        if not os.path.exists(f"./data/vids/{self.file_name}.mp4"):
            raise FileNotFoundError(
                f"Video file ./data/vids/{self.file_name}.mp4 not found")

        # Загрузка субтитров
        subs = pysrt.open(f'./data/subtitles/{self.file_name}.srt')
        self.df = pd.DataFrame([{
            'index': sub.index,
            'start': sub.start.to_time(),
            'end': sub.end.to_time(),
            'text': sub.text
        } for sub in subs])

        # Определение жанра видео
        classifier = pipeline(
            "text-classification",
            model=LOCAL_MODEL_PATH,
            tokenizer=LOCAL_MODEL_PATH,
            #model="handler-bird/movie_genre_multi_classification",
            #tokenizer="distilbert-base-uncased",
            framework="pt"
        )
        self.results = classifier(self.df["text"].tolist()[:100])
        self.genres = Counter([result["label"] for result in self.results])
        self.genre = self.genres.most_common(
            1)[0][0] if self.genres else 'default'

        # Получаем длительность видео
        self.duration = self.get_video_duration(
            f"./data/vids/{self.file_name}.mp4")
        self.total_length = max(self.duration - 4 * 60, 60)  # минимум 1 минута

        # Генерируем recap
        self.recap = self.generate_recap(self.genre, self.total_length)
        self.clips_times = self.get_borders(self.recap)

        # Устанавливаем пути
        self.input_video_path = f"./data/vids/{self.file_name}.mp4"
        self.output_video_path = f"./data/result/{self.file_name}_final_recap.mp4"
        self.list_file = "clips_list.txt"

        # Создаём список клипов и склеиваем их
        self.create_list_file(self.clips_times, self.list_file)
        self.concat_clips()

    def concat_clips(self):
        """
        Объединяет клипы в одно видео с помощью FFmpeg.
        После объединения временные файлы удаляются.
        """
        try:
            subprocess.run([
                "ffmpeg",
                "-f", "concat",
                "-safe", "0",
                "-i", self.list_file,
                "-c", "copy",
                self.output_video_path,
                "-y"
            ], check=True)
        finally:
            # Очистка временных файлов
            for i in range(len(self.clips_times)):
                clip_path = f"clip_{i}.mp4"
                if os.path.exists(clip_path):
                    os.remove(clip_path)
            if os.path.exists(self.list_file):
                os.remove(self.list_file)

    def get_video_duration(self, file_path: str) -> float:
        """
        Возвращает длительность видео в секундах.

        Args:
            file_path (str): Путь к видеофайлу.

        Returns:
            float: Длительность видео в секундах.
        """
        with VideoFileClip(file_path) as clip:
            return clip.duration

    def time_to_seconds(self, time_str: str) -> int:
        """
        Преобразует строку времени формата hh:mm:ss в количество секунд.

        Args:
            time_str (str): Время в виде строки (например, "01:15:30").

        Returns:
            int: Время в секундах.
        """
        if isinstance(time_str, str):
            parts = time_str.split(':')
            if len(parts) == 3:
                h, m, s = parts
                s = s.split('.')[0]  # Отбрасываем миллисекунды
            elif len(parts) == 2:
                m, s = parts
                h = 0
            else:
                return 0
            return int(h) * 3600 + int(m) * 60 + int(s)
        return 0

    def create_list_file(self, clips: List[Tuple[str, str]], list_path: str):
        """
        Создаёт временный файл со списком клипов для FFmpeg.

        Args:
            clips (List[Tuple[str, str]]): Список кортежей (start_time, end_time).
            list_path (str): Путь к выходному файлу.
        """
        with open(list_path, "w") as f:
            for i, (start, end) in enumerate(clips):
                if not start or not end:
                    continue
                start_sec = self.time_to_seconds(start)
                end_sec = self.time_to_seconds(end)
                if start_sec >= end_sec:
                    continue
                clip_name = f"clip_{i}.mp4"
                subprocess.run([
                    "ffmpeg",
                    "-ss", str(start_sec),
                    "-to", str(end_sec),
                    "-i", self.input_video_path,
                    "-c", "copy",
                    clip_name,
                    "-y"
                ], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                f.write(f"file '{clip_name}'\n")

    def get_borders(self, recap_data: Dict[str, Dict]) -> List[Tuple[Optional[str], Optional[str]]]:
        """
        Извлекает временные границы клипов из данных рекэпа.

        Args:
            recap_data (Dict[str, Dict]): Результат функции generate_recap.

        Returns:
            List[Tuple[Optional[str], Optional[str]]]: Список кортежей (start, end).
        """
        return [
            (moment["clip_start"], moment["clip_end"])
            for moment in recap_data.values()
            if moment and moment.get("clip_start") and moment.get("clip_end")
        ]

    def unify_moments(self, genre_data: Dict[str, Dict]) -> Dict[str, Optional[str]]:
        """
        Приводит ключевые моменты конкретного жанра к унифицированному виду.

        Args:
            genre_data (Dict[str, Dict]): Жанровые ключевые моменты.

        Returns:
            Dict[str, Optional[str]]: Маппинг унифицированных ключевых моментов.
        """
        mapping = {key: None for key in self.UNIFIED_KEY_MOMENTS}
        for key in genre_data:
            key_lower = key.lower()
            if "setup" in key_lower or "introduced" in key_lower:
                mapping["setup"] = key
            elif "develop" in key_lower or "gathering" in key_lower:
                mapping["development"] = key
            elif "twist" in key_lower or "false" in key_lower:
                mapping["twist"] = key
            elif "climax" in key_lower or "battle" in key_lower:
                mapping["climax"] = key
            elif "resolution" in key_lower or "ending" in key_lower:
                mapping["resolution"] = key
            elif "cliffhanger" in key_lower or "hint" in key_lower:
                mapping["cliffhanger"] = key
        return mapping

    def generate_recap(self, genre: str, total_seconds: int, chunk_duration: int = 20) -> Dict[str, Dict]:
        """
        Генерирует словарь с ключевыми моментами видео по жанру.

        Args:
            genre (str): Жанр видео.
            total_seconds (int): Общая длина рекэпа в секундах.
            chunk_duration (int): Длительность каждого фрагмента в секундах.

        Returns:
            Dict[str, Dict]: Словарь с ключевыми моментами и временными рамками.
        """
        def seconds_to_time(seconds):
            return str(timedelta(seconds=seconds))

        genre_data = self.genre_dict.get(
            genre.lower(), self.genre_dict["default"])
        mapping = self.unify_moments(genre_data)
        unified_moments = {}

        for unified_key, genre_key in mapping.items():
            if not genre_key:
                continue
            event = genre_data.get(genre_key)
            if not event:
                continue
            start_time = max(
                0, round(total_seconds * event["start_percent"] / 100))
            end_time = min(total_seconds, round(
                total_seconds * event["end_percent"] / 100))
            clip_start_sec = None
            clip_end_sec = None
            if end_time - start_time >= chunk_duration:
                clip_start_sec = random.randint(
                    start_time, end_time - chunk_duration)
                clip_end_sec = clip_start_sec + chunk_duration
            unified_moments[unified_key] = {
                "description": event["description"],
                "start": seconds_to_time(start_time),
                "end": seconds_to_time(end_time),
                "clip_start": seconds_to_time(clip_start_sec) if clip_start_sec else None,
                "clip_end": seconds_to_time(clip_end_sec) if clip_end_sec else None,
            }

        return unified_moments

# %%
# Получаем все .mp4 файлы в указанной директории
video_files = [f for f in os.listdir(VIDEO_DIR) if f.endswith(".mp4")]

for video_file in video_files:
    # Убираем расширение, получаем file_name
    file_name = os.path.splitext(video_file)[0]

    # Формируем пути
    subtitle_path = f"./data/subtitles/{file_name}.srt"
    video_path = f"./data/vids/{file_name}.mp4"

    # Проверяем существование субтитров
    if not os.path.exists(subtitle_path):
        print(f"⚠️ Субтитры для {file_name} не найдены. Пропускаем.")
        continue

    if not os.path.exists(video_path):
        print(f"⚠️ Видео для {file_name} не найдено. Пропускаем.")
        continue

    # Обрабатываем видео
    print(f"🎬 Обрабатываем: {file_name}")
    try:
        recap_video = RecapVideoTransformer(file_name)
        print(f"Готово: {file_name}")
    except Exception as e:
        print(f"Ошибка при обработке {file_name}: {e}")
# Out:
# Device set to use mps:0
# 🎬 Обрабатываем: 15716_2_7
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'isom', 'minor_version': '1', 'compatible_brands': 'isom', 'creation_time': '2023-03-31T13:11:47.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [480, 200], 'bitrate': 550, 'fps': 25.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 128, 'metadata': {'Metadata': '', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1880.08, 'bitrate': 682, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [480, 200], 'video_bitrate': 550, 'video_fps': 25.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 128, 'video_duration': 1880.08, 'video_n_frames': 47002}
# /opt/homebrew/Caskroom/miniconda/base/envs/dlenv/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -i ./data/vids/15716_2_7.mp4 -loglevel error -f image2pipe -vf scale=480:200 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1.1_2 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x1467070c0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'clips_list.txt':
#   Duration: N/A, start: -1.005333, bitrate: 423 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x200, 295 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to './data/result/15716_2_7_final_recap.mp4':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x200, q=2-31, 295 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x146711f40] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x147015c50] Auto-inserting h264_mp4toannexb bitstream filter
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524868, current: 512580; changing to 524869. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969408, current: 1923584; changing to 1969409. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524869, current: 513092; changing to 524870. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969409, current: 1924608; changing to 1969410. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969410, current: 1925632; changing to 1969411. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524870, current: 513604; changing to 524871. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969411, current: 1926656; changing to 1969412. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969412, current: 1927680; changing to 1969413. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524871, current: 514116; changing to 524872. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969413, current: 1928704; changing to 1969414. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969414, current: 1929728; changing to 1969415. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524872, current: 514628; changing to 524873. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969415, current: 1930752; changing to 1969416. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524873, current: 515140; changing to 524874. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969416, current: 1931776; changing to 1969417. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969417, current: 1932800; changing to 1969418. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524874, current: 515652; changing to 524875. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969418, current: 1933824; changing to 1969419. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969419, current: 1934848; changing to 1969420. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524875, current: 516164; changing to 524876. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969420, current: 1935872; changing to 1969421. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969421, current: 1936896; changing to 1969422. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524876, current: 516676; changing to 524877. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969422, current: 1937920; changing to 1969423. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969423, current: 1938944; changing to 1969424. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524877, current: 517188; changing to 524878. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969424, current: 1939968; changing to 1969425. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969425, current: 1940992; changing to 1969426. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524878, current: 517700; changing to 524879. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969426, current: 1942016; changing to 1969427. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969427, current: 1943040; changing to 1969428. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524879, current: 518212; changing to 524880. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969428, current: 1944064; changing to 1969429. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969429, current: 1945088; changing to 1969430. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524880, current: 518724; changing to 524881. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969430, current: 1946112; changing to 1969431. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524881, current: 519236; changing to 524882. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969431, current: 1947136; changing to 1969432. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969432, current: 1948160; changing to 1969433. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524882, current: 519748; changing to 524883. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969433, current: 1949184; changing to 1969434. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969434, current: 1950208; changing to 1969435. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524883, current: 520260; changing to 524884. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969435, current: 1951232; changing to 1969436. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969436, current: 1952256; changing to 1969437. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524884, current: 520772; changing to 524885. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969437, current: 1953280; changing to 1969438. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969438, current: 1954304; changing to 1969439. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524885, current: 521284; changing to 524886. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969439, current: 1955328; changing to 1969440. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969440, current: 1956352; changing to 1969441. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524886, current: 521796; changing to 524887. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969441, current: 1957376; changing to 1969442. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969442, current: 1958400; changing to 1969443. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524887, current: 522308; changing to 524888. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969443, current: 1959424; changing to 1969444. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969444, current: 1960448; changing to 1969445. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524888, current: 522820; changing to 524889. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969445, current: 1961472; changing to 1969446. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524889, current: 523332; changing to 524890. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969446, current: 1962496; changing to 1969447. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969447, current: 1963520; changing to 1969448. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524890, current: 523844; changing to 524891. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969448, current: 1964544; changing to 1969449. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969449, current: 1965568; changing to 1969450. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524891, current: 524356; changing to 524892. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969450, current: 1966592; changing to 1969451. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969451, current: 1967616; changing to 1969452. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x1470143b0] Non-monotonic DTS; previous: 524892, current: 524868; changing to 524893. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x147015090] Non-monotonic DTS; previous: 1969452, current: 1968640; changing to 1969453. This may result in incorrect timestamps in the output file.
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x146707ca0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x146712740] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [out#0/mp4 @ 0x147006100] video:8235KiB audio:1910KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.820933%
# frame= 3056 fps=0.0 q=-1.0 Lsize=   10229KiB time=00:02:01.20 bitrate= 691.4kbits/s speed=3.32e+03x
# Device set to use mps:0
# Готово: 15716_2_7
# 🎬 Обрабатываем: 14194_1_1
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'isom', 'minor_version': '1', 'compatible_brands': 'isom', 'creation_time': '2023-09-11T15:31:45.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [480, 174], 'bitrate': 552, 'fps': 25.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 128, 'metadata': {'Metadata': '', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1205.44, 'bitrate': 684, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [480, 174], 'video_bitrate': 552, 'video_fps': 25.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 128, 'video_duration': 1205.44, 'video_n_frames': 30136}
# /opt/homebrew/Caskroom/miniconda/base/envs/dlenv/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -i ./data/vids/14194_1_1.mp4 -loglevel error -f image2pipe -vf scale=480:174 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1.1_2 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x1367279e0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'clips_list.txt':
#   Duration: N/A, start: -0.053333, bitrate: 609 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x174, 481 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to './data/result/14194_1_1_final_recap.mp4':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x174, q=2-31, 481 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x136612260] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x136727890] Auto-inserting h264_mp4toannexb bitstream filter
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512683, current: 500395; changing to 512684. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512684, current: 500907; changing to 512685. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923456, current: 1878400; changing to 1923457. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923457, current: 1879424; changing to 1923458. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512685, current: 501419; changing to 512686. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923458, current: 1880448; changing to 1923459. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923459, current: 1881472; changing to 1923460. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512686, current: 501931; changing to 512687. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923460, current: 1882496; changing to 1923461. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923461, current: 1883520; changing to 1923462. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512687, current: 502443; changing to 512688. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923462, current: 1884544; changing to 1923463. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923463, current: 1885568; changing to 1923464. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512688, current: 502955; changing to 512689. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923464, current: 1886592; changing to 1923465. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923465, current: 1887616; changing to 1923466. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512689, current: 503467; changing to 512690. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923466, current: 1888640; changing to 1923467. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923467, current: 1889664; changing to 1923468. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512690, current: 503979; changing to 512691. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923468, current: 1890688; changing to 1923469. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923469, current: 1891712; changing to 1923470. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512691, current: 504491; changing to 512692. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923470, current: 1892736; changing to 1923471. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512692, current: 505003; changing to 512693. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923471, current: 1893760; changing to 1923472. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923472, current: 1894784; changing to 1923473. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512693, current: 505515; changing to 512694. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923473, current: 1895808; changing to 1923474. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923474, current: 1896832; changing to 1923475. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512694, current: 506027; changing to 512695. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923475, current: 1897856; changing to 1923476. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923476, current: 1898880; changing to 1923477. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512695, current: 506539; changing to 512696. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923477, current: 1899904; changing to 1923478. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923478, current: 1900928; changing to 1923479. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512696, current: 507051; changing to 512697. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923479, current: 1901952; changing to 1923480. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923480, current: 1902976; changing to 1923481. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512697, current: 507563; changing to 512698. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923481, current: 1904000; changing to 1923482. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923482, current: 1905024; changing to 1923483. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512698, current: 508075; changing to 512699. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923483, current: 1906048; changing to 1923484. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923484, current: 1907072; changing to 1923485. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512699, current: 508587; changing to 512700. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923485, current: 1908096; changing to 1923486. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512700, current: 509099; changing to 512701. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923486, current: 1909120; changing to 1923487. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923487, current: 1910144; changing to 1923488. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512701, current: 509611; changing to 512702. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923488, current: 1911168; changing to 1923489. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923489, current: 1912192; changing to 1923490. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512702, current: 510123; changing to 512703. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923490, current: 1913216; changing to 1923491. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923491, current: 1914240; changing to 1923492. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512703, current: 510635; changing to 512704. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923492, current: 1915264; changing to 1923493. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923493, current: 1916288; changing to 1923494. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512704, current: 511147; changing to 512705. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923494, current: 1917312; changing to 1923495. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923495, current: 1918336; changing to 1923496. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512705, current: 511659; changing to 512706. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923496, current: 1919360; changing to 1923497. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923497, current: 1920384; changing to 1923498. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512706, current: 512171; changing to 512707. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923498, current: 1921408; changing to 1923499. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923499, current: 1922432; changing to 1923500. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x137809330] Non-monotonic DTS; previous: 512707, current: 512683; changing to 512708. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x13780a010] Non-monotonic DTS; previous: 1923500, current: 1923456; changing to 1923501. This may result in incorrect timestamps in the output file.
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x136727890] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x136611cd0] Auto-inserting h264_mp4toannexb bitstream filter
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x1266041d0] Auto-inserting h264_mp4toannexb bitstream filter
# [out#0/mp4 @ 0x137808950] video:8192KiB audio:1895KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.816160%
# frame= 3031 fps=0.0 q=-1.0 Lsize=   10169KiB time=00:02:00.45 bitrate= 691.6kbits/s speed=3.15e+03x
# Device set to use mps:0
# Готово: 14194_1_1
# 🎬 Обрабатываем: 15716_1_1
# {'video_found': True, 'audio_found': True, 'metadata': {'major_brand': 'isom', 'minor_version': '1', 'compatible_brands': 'isom', 'creation_time': '2023-07-03T16:11:56.000000Z'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [480, 202], 'bitrate': 552, 'fps': 25.0, 'codec_name': 'h264', 'profile': '(Main)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}, {'input_number': 0, 'stream_number': 1, 'stream_type': 'audio', 'language': None, 'default': True, 'fps': 48000, 'bitrate': 128, 'metadata': {'Metadata': '', 'handler_name': 'SoundHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1812.36, 'bitrate': 684, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'h264', 'video_profile': '(Main)', 'video_size': [480, 202], 'video_bitrate': 552, 'video_fps': 25.0, 'default_audio_input_number': 0, 'default_audio_stream_number': 1, 'audio_fps': 48000, 'audio_bitrate': 128, 'video_duration': 1812.36, 'video_n_frames': 45309}
# /opt/homebrew/Caskroom/miniconda/base/envs/dlenv/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-macos-aarch64-v7.1 -i ./data/vids/15716_1_1.mp4 -loglevel error -f image2pipe -vf scale=480:202 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# Готово: 15716_1_1
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 16.0.0 (clang-1600.0.26.6)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1.1_2 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x143f329c0] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'clips_list.txt':
#   Duration: N/A, start: -0.053333, bitrate: 686 kb/s
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x202, 558 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Output #0, mp4, to './data/result/15716_1_1_final_recap.mp4':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 480x202, q=2-31, 558 kb/s, 25 fps, 25 tbr, 12800 tbn
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x144907d00] Auto-inserting h264_mp4toannexb bitstream filter
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256171, current: 243883; changing to 256172. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961536, current: 915712; changing to 961537. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256172, current: 244395; changing to 256173. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961537, current: 916736; changing to 961538. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961538, current: 917760; changing to 961539. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256173, current: 244907; changing to 256174. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961539, current: 918784; changing to 961540. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961540, current: 919808; changing to 961541. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256174, current: 245419; changing to 256175. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961541, current: 920832; changing to 961542. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961542, current: 921856; changing to 961543. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256175, current: 245931; changing to 256176. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961543, current: 922880; changing to 961544. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961544, current: 923904; changing to 961545. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256176, current: 246443; changing to 256177. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961545, current: 924928; changing to 961546. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961546, current: 925952; changing to 961547. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256177, current: 246955; changing to 256178. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961547, current: 926976; changing to 961548. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256178, current: 247467; changing to 256179. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961548, current: 928000; changing to 961549. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961549, current: 929024; changing to 961550. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256179, current: 247979; changing to 256180. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961550, current: 930048; changing to 961551. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961551, current: 931072; changing to 961552. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256180, current: 248491; changing to 256181. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961552, current: 932096; changing to 961553. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961553, current: 933120; changing to 961554. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256181, current: 249003; changing to 256182. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961554, current: 934144; changing to 961555. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961555, current: 935168; changing to 961556. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256182, current: 249515; changing to 256183. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961556, current: 936192; changing to 961557. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961557, current: 937216; changing to 961558. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256183, current: 250027; changing to 256184. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961558, current: 938240; changing to 961559. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961559, current: 939264; changing to 961560. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256184, current: 250539; changing to 256185. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961560, current: 940288; changing to 961561. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961561, current: 941312; changing to 961562. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256185, current: 251051; changing to 256186. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961562, current: 942336; changing to 961563. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256186, current: 251563; changing to 256187. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961563, current: 943360; changing to 961564. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961564, current: 944384; changing to 961565. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256187, current: 252075; changing to 256188. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961565, current: 945408; changing to 961566. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961566, current: 946432; changing to 961567. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256188, current: 252587; changing to 256189. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961567, current: 947456; changing to 961568. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961568, current: 948480; changing to 961569. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256189, current: 253099; changing to 256190. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961569, current: 949504; changing to 961570. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961570, current: 950528; changing to 961571. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256190, current: 253611; changing to 256191. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961571, current: 951552; changing to 961572. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961572, current: 952576; changing to 961573. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256191, current: 254123; changing to 256192. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961573, current: 953600; changing to 961574. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961574, current: 954624; changing to 961575. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256192, current: 254635; changing to 256193. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961575, current: 955648; changing to 961576. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961576, current: 956672; changing to 961577. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256193, current: 255147; changing to 256194. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 961577, current: 957696; changing to 961578. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 256194, current: 255659; changing to 256195. This may result in incorrect timestamps in the output file.
# ...
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769210, current: 764587; changing to 769211. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886171, current: 2867456; changing to 2886172. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886172, current: 2868480; changing to 2886173. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769211, current: 765099; changing to 769212. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886173, current: 2869504; changing to 2886174. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886174, current: 2870528; changing to 2886175. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769212, current: 765611; changing to 769213. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886175, current: 2871552; changing to 2886176. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886176, current: 2872576; changing to 2886177. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769213, current: 766123; changing to 769214. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886177, current: 2873600; changing to 2886178. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886178, current: 2874624; changing to 2886179. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769214, current: 766635; changing to 769215. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886179, current: 2875648; changing to 2886180. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886180, current: 2876672; changing to 2886181. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769215, current: 767147; changing to 769216. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886181, current: 2877696; changing to 2886182. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769216, current: 767659; changing to 769217. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886182, current: 2878720; changing to 2886183. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886183, current: 2879744; changing to 2886184. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769217, current: 768171; changing to 769218. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886184, current: 2880768; changing to 2886185. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886185, current: 2881792; changing to 2886186. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769218, current: 768683; changing to 769219. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886186, current: 2882816; changing to 2886187. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886187, current: 2883840; changing to 2886188. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 769219, current: 769195; changing to 769220. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886188, current: 2884864; changing to 2886189. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 2886189, current: 2885888; changing to 2886190. This may result in incorrect timestamps in the output file.
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x143f35a30] Auto-inserting h264_mp4toannexb bitstream filter
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025707, current: 1014443; changing to 1025708. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025708, current: 1014955; changing to 1025709. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847424, current: 3806080; changing to 3847425. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847425, current: 3807104; changing to 3847426. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025709, current: 1015467; changing to 1025710. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847426, current: 3808128; changing to 3847427. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847427, current: 3809152; changing to 3847428. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025710, current: 1015979; changing to 1025711. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847428, current: 3810176; changing to 3847429. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847429, current: 3811200; changing to 3847430. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025711, current: 1016491; changing to 1025712. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847430, current: 3812224; changing to 3847431. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847431, current: 3813248; changing to 3847432. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025712, current: 1017003; changing to 1025713. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847432, current: 3814272; changing to 3847433. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847433, current: 3815296; changing to 3847434. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025713, current: 1017515; changing to 1025714. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847434, current: 3816320; changing to 3847435. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847435, current: 3817344; changing to 3847436. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025714, current: 1018027; changing to 1025715. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847436, current: 3818368; changing to 3847437. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847437, current: 3819392; changing to 3847438. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025715, current: 1018539; changing to 1025716. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847438, current: 3820416; changing to 3847439. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025716, current: 1019051; changing to 1025717. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847439, current: 3821440; changing to 3847440. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847440, current: 3822464; changing to 3847441. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025717, current: 1019563; changing to 1025718. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847441, current: 3823488; changing to 3847442. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847442, current: 3824512; changing to 3847443. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025718, current: 1020075; changing to 1025719. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847443, current: 3825536; changing to 3847444. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847444, current: 3826560; changing to 3847445. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025719, current: 1020587; changing to 1025720. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847445, current: 3827584; changing to 3847446. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847446, current: 3828608; changing to 3847447. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025720, current: 1021099; changing to 1025721. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847447, current: 3829632; changing to 3847448. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847448, current: 3830656; changing to 3847449. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025721, current: 1021611; changing to 1025722. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847449, current: 3831680; changing to 3847450. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847450, current: 3832704; changing to 3847451. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025722, current: 1022123; changing to 1025723. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847451, current: 3833728; changing to 3847452. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847452, current: 3834752; changing to 3847453. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025723, current: 1022635; changing to 1025724. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847453, current: 3835776; changing to 3847454. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025724, current: 1023147; changing to 1025725. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847454, current: 3836800; changing to 3847455. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847455, current: 3837824; changing to 3847456. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025725, current: 1023659; changing to 1025726. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847456, current: 3838848; changing to 3847457. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847457, current: 3839872; changing to 3847458. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025726, current: 1024171; changing to 1025727. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847458, current: 3840896; changing to 3847459. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847459, current: 3841920; changing to 3847460. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025727, current: 1024683; changing to 1025728. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847460, current: 3842944; changing to 3847461. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847461, current: 3843968; changing to 3847462. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025728, current: 1025195; changing to 1025729. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847462, current: 3844992; changing to 3847463. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847463, current: 3846016; changing to 3847464. This may result in incorrect timestamps in the output file.
# [vost#0:0/copy @ 0x143f40360] Non-monotonic DTS; previous: 1025729, current: 1025707; changing to 1025730. This may result in incorrect timestamps in the output file.
# [aost#0:1/copy @ 0x143f40fe0] Non-monotonic DTS; previous: 3847464, current: 3847040; changing to 3847465. This may result in incorrect timestamps in the output file.
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x144907550] Auto-inserting h264_mp4toannexb bitstream filter
# [out#0/mp4 @ 0x143f3f980] video:9597KiB audio:1926KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.734478%
# frame= 3081 fps=0.0 q=-1.0 Lsize=   11607KiB time=00:02:00.41 bitrate= 789.7kbits/s speed=3.16e+03x

# %%
#test = RecapVideoTransformer(file_name)
