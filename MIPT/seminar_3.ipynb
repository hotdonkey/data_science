# %% [markdown]
# На этом практическом занятии мы будем работать с датасетом Titanic
#
# Информация о столбцах:
#
# - **PassengerId**: уникальный id пассажира
# - **Pclass**: класс каюты, в которой ехал пассажир (1, 2 или 3)
# - **Name**: имя пассажира
# - **Sex**: пол пассажира
# - **Age**: возраст пассажира
# - **SibSp**: общее количество братьев, сестер и супругов пассажира, которые также ехали на Титанике
# - **Parch**: общее количество родителей и детей пассажира, которые также ехали на Титанике
# - **Ticket**: номер билета пассажира
# - **Fare**: стоимость билета пассажира
# - **Cabin**: номер каюты пассажира
# - **Embarked**: в каком порту пассажир сел на Титаник:
#   - **S**: Southhampton
#   - **C**: Cherbourg
#   - **Q**: Queenstown

# %% [markdown]
# # Задания с использованием библиотеки Pandas

# %% [markdown]
# 1. Загрузите датасет Titanic и выведите первые и последние 10 строк. Проверьте типы данных для каждой колонки, есть ли пропущенные значения, и определите размер датасета.
#
# Подсказка: DataFrame считывается, как обычный *.csv файл. В скобках нужно будет указать переменную url вместо 'название_файла.csv'
#
# Каждое действие можно делать отдельно в новой ячейки в jupyter notebook

# %%
import pandas as pd

# Прямая ссылка на csv файл
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# Загрузка датасета
# ваш код

# %%
data = pd.read_csv('./data/titanic_downdloaded.csv',)

# %%
display(data.head(10), data.tail(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# 2. Найдите количество пропущенных значений в колонке 'Age'. Заполните пропуски в 'Age' средним возрастом и убедитесь, что пропущенных данных больше нет.

# %%
data["Age"] = data["Age"].fillna(value=data["Age"].mean())
print(data.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 3. Создайте новую колонку 'FamilySize', которая вычисляет количество членов семьи пассажира (складывая колонки 'SibSp' и 'Parch'). Выведите первых 10 строк с новой колонкой.

# %%
data["FamilySize"] = data["SibSp"] + data["Parch"]
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      1      0         A/5 21171   7.2500   NaN        S           1
# 1      1      0          PC 17599  71.2833   C85        C           1
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S           0
# 3      1      0            113803  53.1000  C123        S           1
# 4      0      0            373450   8.0500   NaN        S           0
# 5      0      0            330877   8.4583   NaN        Q           0
# 6      0      0             17463  51.8625   E46        S           0
# 7      3      1            349909  21.0750   NaN        S           4
# 8      0      2            347742  11.1333   NaN        S           2
# 9      1      0            237736  30.0708   NaN        C           1

# %% [markdown]
# 4. Посчитайте минимальный, максимальный возраст пассажиров, а также минимальную и максимальную цену билета (Fare) для каждой группы пассажиров по полу ('Sex') и классу ('Pclass').

# %%
data.groupby(by=["Sex", "Pclass"])[["Fare", "Age"]].agg(
    {"Age": ["min", "max"], "Fare": ["min", "max"]}
)
# Out:
#                 Age           Fare
#                 min   max      min       max
# Sex    Pclass
# female 1       2.00  63.0  25.9292  512.3292
#        2       2.00  57.0  10.5000   65.0000
#        3       0.75  63.0   6.7500   69.5500
# male   1       0.92  80.0   0.0000  512.3292
#        2       0.67  70.0   0.0000   73.5000
#        3       0.42  74.0   0.0000   69.5500

# %% [markdown]
# 5. Выведите всех пассажиров, чей возраст больше 50 лет и кто путешествовал в первом классе.

# %%
data.query("Age > 50 and Pclass == 1")
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 54            55         0       1
# 96            97         0       1
# 124          125         0       1
# 155          156         0       1
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 252          253         0       1
# 262          263         0       1
# 268          269         1       1
# 275          276         1       1
# 366          367         1       1
# 438          439         0       1
# 449          450         1       1
# 456          457         0       1
# 467          468         0       1
# 487          488         0       1
# 492          493         0       1
# 493          494         0       1
# 496          497         1       1
# 513          514         1       1
# 545          546         0       1
# 555          556         0       1
# 571          572         1       1
# 587          588         1       1
# 591          592         1       1
# 625          626         0       1
# 630          631         1       1
# 647          648         1       1
# 659          660         0       1
# 694          695         0       1
# 745          746         0       1
# 765          766         1       1
# 820          821         1       1
# 829          830         1       1
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 124                        White, Mr. Percival Wayland    male  54.0      0
# 155                        Williams, Mr. Charles Duane    male  51.0      0
# 170                          Van der hoef, Mr. Wyckoff    male  61.0      0
# 174                            Smith, Mr. James Clinch    male  56.0      0
# 195                               Lurette, Miss. Elise  female  58.0      0
# 252                          Stead, Mr. William Thomas    male  62.0      0
# 262                                  Taussig, Mr. Emil    male  52.0      1
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 275                  Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 438                                  Fortune, Mr. Mark    male  64.0      1
# 449                     Peuchen, Major. Arthur Godfrey    male  52.0      0
# 456                          Millet, Mr. Francis Davis    male  65.0      0
# 467                         Smart, Mr. John Montgomery    male  56.0      0
# 487                            Kent, Mr. Edward Austin    male  58.0      0
# 492                         Molson, Mr. Harry Markland    male  55.0      0
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# 496                     Eustis, Miss. Elizabeth Mussey  female  54.0      1
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 545                       Nicholson, Mr. Arthur Ernest    male  64.0      0
# 555                                 Wright, Mr. George    male  62.0      0
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0      2
# 587                   Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
# 625                              Sutton, Mr. Frederick    male  61.0      0
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 647                Simonius-Blumer, Col. Oberst Alfons    male  56.0      0
# 659                         Newell, Mr. Arthur Webster    male  58.0      0
# 694                                    Weir, Col. John    male  60.0      0
# 745                       Crosby, Capt. Edward Gifford    male  70.0      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch     Ticket      Fare        Cabin Embarked  FamilySize
# 6        0      17463   51.8625          E46        S           0
# 11       0     113783   26.5500         C103        S           0
# 54       1     113509   61.9792          B30        C           1
# 96       0   PC 17754   34.6542           A5        C           0
# 124      1      35281   77.2875          D26        S           1
# 155      1   PC 17597   61.3792          NaN        C           1
# 170      0     111240   33.5000          B19        S           0
# 174      0      17764   30.6958           A7        C           0
# 195      0   PC 17569  146.5208          B80        C           0
# 252      0     113514   26.5500          C87        S           0
# 262      1     110413   79.6500          E67        S           2
# 268      1   PC 17582  153.4625         C125        S           1
# 275      0      13502   77.9583           D7        S           1
# 366      0     110813   75.2500          D37        C           1
# 438      4      19950  263.0000  C23 C25 C27        S           5
# 449      0     113786   30.5000         C104        S           0
# 456      0      13509   26.5500          E38        S           0
# 467      0     113792   26.5500          NaN        S           0
# 487      0      11771   29.7000          B37        C           0
# 492      0     113787   30.5000          C30        S           0
# 493      0   PC 17609   49.5042          NaN        C           0
# 496      0      36947   78.2667          D20        C           1
# 513      0   PC 17603   59.4000          NaN        C           1
# 545      0        693   26.0000          NaN        S           0
# 555      0     113807   26.5500          NaN        S           0
# 571      0      11769   51.4792         C101        S           2
# 587      1      13567   79.2000          B41        C           2
# 591      0      36947   78.2667          D20        C           1
# 625      0      36963   32.3208          D50        S           0
# 630      0      27042   30.0000          A23        S           0
# 647      0      13213   35.5000          A26        C           0
# 659      2      35273  113.2750          D48        C           2
# 694      0     113800   26.5500          NaN        S           0
# 745      1  WE/P 5735   71.0000          B22        S           2
# 765      0      13502   77.9583          D11        S           1
# 820      1      12749   93.5000          B69        S           2
# 829      0     113572   80.0000          B28      NaN           0
# 857      0     113055   26.5500          E17        S           0
# 879      1      11767   83.1583          C50        C           1

# %% [markdown]
# 6. Вычислите процент выживших пассажиров в зависимости от пола ('Sex') и класса ('Pclass') до 2ух знаков после запятой. Выведите результат в виде таблицы.

# %%
result = data.groupby(by=["Sex", "Pclass"])["Survived"].mean() * 100
result = round(result, 2)
print(result)
# Out:
# Sex     Pclass
# female  1         96.81
#         2         92.11
#         3         50.00
# male    1         36.89
#         2         15.74
#         3         13.54
# Name: Survived, dtype: float64

# %% [markdown]
# 7. Удалите колонку 'Cabin', так как она содержит слишком много пропущенных значений. Убедитесь, что колонка удалена.

# %%
data.drop(columns=["Cabin"], inplace=True)
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Embarked  FamilySize
# 0      1      0         A/5 21171   7.2500        S           1
# 1      1      0          PC 17599  71.2833        C           1
# 2      0      0  STON/O2. 3101282   7.9250        S           0
# 3      1      0            113803  53.1000        S           1
# 4      0      0            373450   8.0500        S           0
# 5      0      0            330877   8.4583        Q           0
# 6      0      0             17463  51.8625        S           0
# 7      3      1            349909  21.0750        S           4
# 8      0      2            347742  11.1333        S           2
# 9      1      0            237736  30.0708        C           1

# %% [markdown]
# 8. Отсортируйте данные по возрасту пассажиров в порядке убывания и выведите первые 10 строк отсортированного датасета.

# %%
data.sort_values(by="Age", ascending=False).head(10)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 33            34         0       2                 Wheadon, Mr. Edward H
# 456          457         0       1             Millet, Mr. Francis Davis
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Embarked  FamilySize
# 630  male  80.0      0      0       27042  30.0000        S           0
# 851  male  74.0      0      0      347060   7.7750        S           0
# 96   male  71.0      0      0    PC 17754  34.6542        C           0
# 493  male  71.0      0      0    PC 17609  49.5042        C           0
# 116  male  70.5      0      0      370369   7.7500        Q           0
# 672  male  70.0      0      0  C.A. 24580  10.5000        S           0
# 745  male  70.0      1      1   WE/P 5735  71.0000        S           2
# 33   male  66.0      0      0  C.A. 24579  10.5000        S           0
# 456  male  65.0      0      0       13509  26.5500        S           0
# 54   male  65.0      0      1      113509  61.9792        C           1

# %% [markdown]
# 9. Создайте сводную таблицу, которая покажет среднюю стоимость билета (Fare) и возраст (Age) для пассажиров по полу и классу.

# %%
pivot_table = data.pivot_table(
    index="Sex", columns="Pclass", values=["Fare", "Age"], aggfunc="mean"
)
display(pivot_table)
# Out:
#               Age                              Fare
# Pclass          1          2          3           1          2          3
# Sex
# female  34.141405  28.748661  24.068493  106.125798  21.970121  16.118810
# male    39.287717  30.653908  27.372153   67.226127  19.741782  12.661633

# %% [markdown]
# 10. Преобразуйте колонку 'Name', чтобы извлечь статус (например, 'Mr.', 'Mrs.', 'Miss.') для каждого пассажира и добавьте новую колонку 'Title'. Выведите 5 строк с новой колонкой.

# %%
status = pd.DataFrame(data["Name"].str.split(expand=True)[1])
status = status.rename(columns={1:"Title"})
data["Title"] = status["Title"]
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  29.699118
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# 7                     Palsson, Master. Gosta Leonard    male   2.000000
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
#
#    SibSp  Parch            Ticket     Fare Embarked  FamilySize    Title
# 0      1      0         A/5 21171   7.2500        S           1      Mr.
# 1      1      0          PC 17599  71.2833        C           1     Mrs.
# 2      0      0  STON/O2. 3101282   7.9250        S           0    Miss.
# 3      1      0            113803  53.1000        S           1     Mrs.
# 4      0      0            373450   8.0500        S           0      Mr.
# 5      0      0            330877   8.4583        Q           0      Mr.
# 6      0      0             17463  51.8625        S           0      Mr.
# 7      3      1            349909  21.0750        S           4  Master.
# 8      0      2            347742  11.1333        S           2     Mrs.
# 9      1      0            237736  30.0708        C           1     Mrs.

# %% [markdown]
# # Задания с использованием библиотеки Matplotlib

# %% [markdown]
# 11. Постройте гистограмму распределения возраста пассажиров с 20 интервалами. Выведите название таблицы "Распределение возраста пассажиров", а также названия оси X "Возраст" и оси Y "Количество пассажиров".
#
# Подсказка: не забудьте сначала импортировать библиотеку Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 12. Постройте диаграмму рассеяния, чтобы отобразить связь между возрастом пассажира и стоимостью его билета. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
plt.scatter(x=data["Age"], y=data["Fare"])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Cтарый и богатый")
plt.show()

# %% [markdown]
# 13. Постройте столбчатую диаграмму, отображающую количество выживших и погибших пассажиров в зависимости от пола. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

fig, axes = plt.subplots(1, 1)
sns.countplot(x="Survived", hue="Sex", data=data, ax=axes)
plt.title("Мужики умирают")
plt.xlabel("Выжили")
plt.ylabel("Количество")
plt.show()

# %%
survived_by_sex = data.groupby('Sex')['Survived'].value_counts().unstack()
survived_by_sex.plot(kind='bar')

plt.title('Мужики умирают криво')
plt.xlabel('Пол')
plt.ylabel('Количество пассажиров')
plt.xticks(rotation=0)
plt.legend(title='Выжил', labels=['Нет', 'Да'])
plt.show()

# %% [markdown]
# 14. Постройте круговую диаграмму, которая отобразит процент выживших и погибших пассажиров. Сделайте необходимые подписи, дайте название диаграмме и выведите их. Доля погибших пассажиров должна быть - **красной**, а выживших - **зеленой**. Также выведите проценты внутри долей!

# %%
survived_count = data[data['Survived'] == 1].shape[0]
not_survived_count = data[data['Survived'] == 0].shape[0]

labels = 'Выжившие', 'Погибшие'
sizes = [survived_count, not_survived_count]
colors = ['green', 'red']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Окружность

plt.title("Процент выживших и погибших пассажиров")
plt.show()

# %% [markdown]
# 15. Постройте диаграмму boxplot для распределения стоимости билетов с разбивкой по классам пассажиров. Уберите автоматический заголовок и выведите свой заголовок с подписанными осями.

# %%
fig, axes = plt.subplots(1, 1, figsize=(20,10))
box_data = [data[data["Pclass"] == 1]["Fare"], 
            data[data["Pclass"] == 2]["Fare"], 
            data[data["Pclass"] == 3]["Fare"]]

plt.boxplot(box_data, labels=["1 класс", "2 класс", "3 класс"])
plt.xlabel("Цена")
plt.ylabel("Тариф")
plt.title("Ящик с усами для тарифов в зависимости от класса")
plt.show()

# %% [markdown]
# 16. Постройте линейный график, отображающий количество пассажиров в зависимости от их возраста (сгруппированного по 5 лет). Дайте подходящее название графику, подпишите оси!

# %%
age_groups = list(range(int(data["Age"].min()), int(data["Age"].max()), 5))
passengers_by_age = data.groupby(pd.cut(data['Age'], age_groups)).size()

plt.plot(passengers_by_age.index.astype(str), passengers_by_age.values, marker='o')
plt.title('Количество пассажиров по возрастным группам')
plt.xlabel('Возрастные группы')
plt.ylabel('Количество пассажиров')
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(data["Age"], bins=20)
# Out:
# (array([ 40.,  14.,  15.,  31.,  79.,  98.,  85., 261.,  73.,  45.,  35.,
#          35.,  29.,  16.,  13.,  11.,   4.,   5.,   1.,   1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# 17. Постройте гистограмму, отображающую распределение количества членов семьи у пассажиров. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код

# %% [markdown]
# 18. Постройте многослойную столбчатую диаграмму, отображающую выживаемость пассажиров по классам с разбивкой по полу. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код

# %% [markdown]
# 19. Постройте столбчатую диаграмму, отображающую средний возраст выживших и погибших пассажиров. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код

# %% [markdown]
# 20. Постройте столбчатую диаграмму, отображающую количество пассажиров, отправившихся из каждого порта (колонка 'Embarked'). Отобразите порты 'C' (Cherbourg) - желтый цвет, 'Q' (Queenstown) - зеленый цвет, и 'S' (Southampton) - синий цвет. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код

# %% [markdown]
# # Задания с использованием библиотеки Seaborn

# %% [markdown]
# 21. Постройте тепловую карту (heatmap) для отображения корреляции между **числовыми** признаками датасета. Дайте и выведите название этой матрицы!

# %%
sns.heatmap(data.corr(numeric_only=True))
plt.title("КОРРЕЛЯЦИЯ!!")
plt.show()

# %% [markdown]
# 22. Постройте jointplot, отображающий диаграмму рассеяния возраста и стоимости билета с плотностями распределения по осям. Подпишите оси!

# %%
sns.jointplot(x=data["Age"], y=data["Fare"])
plt.show()

# %% [markdown]
# 23. Постройте swarmplot, чтобы отобразить возраст пассажиров в зависимости от класса. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
fig, axes= plt.subplots(1, 1, figsize=(20,10))
sns.swarmplot(x="Pclass", y="Age",data=data)
plt.show()

# %% [markdown]
# 24. Постройте сетку графиков с помощью FacetGrid для отображения распределения стоимости билета с разбивкой по полу и порту отправления. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# Создадим объект FacetGrid
g = sns.FacetGrid(data, col="Sex", row="Embarked", margin_titles=True)
g.map(sns.histplot, "Fare", color="steelblue")
g.set_axis_labels("Стоимость билета", "Количество пассажиров")
g.fig.suptitle('Распределение стоимости билета по полу и порту отправления', size=16)
plt.show()

# %%
sns.

# %% [markdown]
# 25. Постройте barplot, который отобразит медианную стоимость билетов с разбивкой по полу и порту отправления. В библиотеке Seaborn можно использовать numpy.median, чтобы задать функцию для estimator. Не забудьте импортировать numpy! Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код

# %% [markdown]
# 26. Постройте pointplot, чтобы показать, как изменяется вероятность выживания в зависимости от пола и класса. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код

# %% [markdown]
# 27. Постройте pairplot для числовых признаков (например, возраста, стоимости билета, количества членов семьи) с разделением по полу.

# %%
# ваш код

# %% [markdown]
# 28. Постройте heatmap, который покажет частоту пересечений возраста и количества членов семьи (колонка SibSp). Дайте соответствующее название вашей heatmap

# %%
# ваш код

# %% [markdown]
# 29. Постройте boxenplot, чтобы показать детализированное распределение стоимости билетов по полу и классу. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код

# %% [markdown]
# 30. Постройте stripplot, чтобы визуализировать распределение возраста пассажиров по классам, а также добавьте разбивку по полу. Придумайте и выведите соответсвтующее название диагарммы, а также подпишите оси!

# %%
# ваш код
