# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DF").master("yarn").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://46.148.235.141:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Но при этом из этого контекста не вызывается ID пиложения

# %%
spark.applicationId
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 spark.applicationId
#
# AttributeError: 'SparkSession' object has no attribute 'applicationId'

# %%
sc.applicationId
# Out:
# 'application_1750716381279_1632'

# %%
sc
# Out:
# <SparkContext master=yarn appName=PySparkShell>

# %% [markdown]
# ---
# ### Загрузим данные

# %%
# %%time
df = (spark.read.format("json").load("/data/yelp/review"))
# Out:
# CPU times: user 33.1 ms, sys: 21.9 ms, total: 54.9 ms
# Wall time: 16.5 s

# %%
df.head()
# Out:
# Row(business_id='XQfwVwDr-v0ZS3_CbbE5Xw', cool=0, date='2018-07-07 22:09:11', funny=0, review_id='KU_O5udG6zpxOg-VcAEodg', stars=3.0, text="If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.", useful=0, user_id='mh_-eMZ6K5RLWhZyISBhwA')

# %% [markdown]
# #### Можно посмотреть структуру

# %%
df.printSchema()
# Out:
# root
#  |-- business_id: string (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- date: string (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- user_id: string (nullable = true)

# %%
df.show(1, vertical=True, truncate=False)
# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | XQfwVwDr-v0ZS3_CbbE5Xw
#  cool        | 0
#  date        | 2018-07-07 22:09:11
#  funny       | 0
#  review_id   | KU_O5udG6zpxOg-VcAEodg
#  stars       | 3.0
#  text        | If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.
#  useful      | 0
#  user_id     | mh_-eMZ6K5RLWhZyISBhwA
# only showing top 1 row

# %% [markdown]
# ### Аналог padndas.describe()

# %%
df.summary().show(10, truncate=False, vertical=True)
# Out:
# [Stage 10:>                                                         (0 + 1) / 1]
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  summary     | count
#  business_id | 6990280
#  cool        | 6990280
#  date        | 6990280
#  funny       | 6990280
#  review_id   | 6990280
#  stars       | 6990280
#  text        | 6990280
#  useful      | 6990280
#  user_id     | 6990280
# -RECORD 1--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  summary     | mean
#  business_id | null
#  cool        | 0.4986175088837643
#  date        | null
#  funny       | 0.32655959417934616
#  review_id   | null
#  stars       | 3.74858374771826
#  text        | null
#  useful      | 1.1846089140921394
#  user_id     | null
# -RECORD 2--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  summary     | stddev
#  business_id | null
#  cool        | 2.172459820211187
#  date        | null
#  funny       | 1.6887290985540495
#  review_id   | null
#  stars       | 1.4787045052556855
#  text        | null
#  useful      | 3.2537669669333638
#  user_id     | null
# -RECORD 3--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  summary     | min
#  business_id | ---kPU91CF4Lq2-WlRu9Lw
#  cool        | -1
#  date        | 2005-02-16 03:23:22
#  funny       | -1
# ...
#  useful      | 1
#  user_id     | null
# -RECORD 7--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  summary     | max
#  business_id | zzyx5x0Z7xXWWvWnZFuxlQ
#  cool        | 404
#  date        | 2022-01-19 19:48:45
#  funny       | 792
#  review_id   | zzzz1ADBqBEVyfX4lGnQ3Q
#  stars       | 5.0
#  text        | ＼(^o^)／\nThey have a different taste than most donuts, but they're really good. I have yet to try the chicken, but it smells good! \nI like how they have regular and fancy donuts ^_^\nIt's a very unique place, definitely worth a visit!
#  useful      | 1182
#  user_id     | zzzUFM4HFe0SFG0bPjntQA
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.summary().show(10, truncate=False, vertical=True).cache()
#
# AttributeError: 'NoneType' object has no attribute 'cache'

# %% [markdown]
# ---
# ### Переход от RDD к DataFrames

# %%
import json
rdd = sc.textFile("/data/yelp/review").map(lambda x: json.loads(x))

# %% [markdown]
# #### Превращаем rdd в таблицу

# %%
df_rdd = spark.createDataFrame(rdd)

# %%
df_rdd.show(1)
# Out:
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|   0|2018-07-07 22:09:11|    0|KU_O5udG6zpxOg-Vc...|  3.0|If you decide to ...|     0|mh_-eMZ6K5RLWhZyI...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 1 row

# %%
df_rdd.printSchema()
# Out:
# root
#  |-- business_id: string (nullable = true)
#  |-- cool: long (nullable = true)
#  |-- date: string (nullable = true)
#  |-- funny: long (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- text: string (nullable = true)
#  |-- useful: long (nullable = true)
#  |-- user_id: string (nullable = true)

# %% [markdown]
# #### Аналог pandas.columns().to_list()

# %%
df_rdd.schema.fieldNames()
# Out:
# ['business_id',
#  'cool',
#  'date',
#  'funny',
#  'review_id',
#  'stars',
#  'text',
#  'useful',
#  'user_id']

# %% [markdown]
# #### Слайс колонок

# %%
df_rdd.select(["business_id", "stars", "text"]).show(5, truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | XQfwVwDr-v0ZS3_CbbE5Xw
#  stars       | 3.0
#  text        | If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.
# -RECORD 1------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | 7ATYjTIgM3jUlt4UM3IypQ
#  stars       | 5.0
#  text        | I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do).\n\nThere is no way I can write this review without giving Russell, the owner of Body Cycle, a shout out. Russell's passion for fitness and cycling is so evident, as is his desire for all of his clients to succeed. He is always dropping in to classes to check in/provide encouragement, and is open to ideas and recommendations from anyone. Russell always wears a smile on his face, even when he's kicking your butt in class!
# -RECORD 2------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | YjUWPpI6HXG530lwP-fb2A
#  stars       | 3.0
#  text        | Family diner. Had the buffet. Eclectic assortment: a large chicken leg, fried jalapeño, tamale, two rolled grape leaves, fresh melon. All good. Lots of Mexican choices there. Also has a menu with breakfast served all day long. Friendly, attentive staff. Good place for a casual relaxed meal with no expectations. Next to the Clarion Hotel.
# -RECORD 3------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | kxX2SOes4o-D3ZQBkiMRfA
#  stars       | 5.0
#  text        | Wow!  Yummy, different,  delicious.   Our favorite is the lamb curry and korma.  With 10 different kinds of naan!!!  Don't let the outside deter you (because we almost changed our minds)...go in and try something new!   You'll be glad you did!
# -RECORD 4------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | e4Vwtrqf-wpJfwesgvdgxQ
#  stars       | 4.0
#  text        | Cute interior and owner (?) gave us tour of upcoming patio/rooftop area which will be great on beautiful days like today. Cheese curds were very good and very filling. Really like that sandwiches come w salad, esp after eating too many curds! Had the onion, gruyere, tomato sandwich. Wasn't too much cheese which I liked. Needed something else...pepper jelly maybe. Would like to see more menu options added such as salads w fun cheeses. Lots of beer and wine as well as limited cocktails. Next time I will try one of the draft wines.
# only showing top 5 rows

# %% [markdown]
# #### Вывод списка колонок через select

# %%
df_rdd.select(*df.schema.fieldNames())
# Out:
# DataFrame[business_id: string, cool: bigint, date: string, funny: bigint, review_id: string, stars: double, text: string, useful: bigint, user_id: string]

# %% [markdown]
# ---
# ### Способы фильтрации

# %%
df_rdd.where('stars == 3').show(5)
# Out:
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|   0|2018-07-07 22:09:11|    0|KU_O5udG6zpxOg-Vc...|  3.0|If you decide to ...|     0|mh_-eMZ6K5RLWhZyI...|
# |YjUWPpI6HXG530lwP...|   0|2014-02-05 20:30:30|    0|saUsX_uimxRlCVr67...|  3.0|Family diner. Had...|     0|8g_iMtfSiwikVnbP2...|
# |B5XSoSG3SfvQGtKEG...|   0|2016-03-30 22:46:33|    1|ZKvDG2sBvHVdF5oBN...|  3.0|This easter inste...|     1|wSTuiTk-sKNdcFypr...|
# |gebiRewfieSdtt17P...|   0|2016-07-25 07:31:06|    0|pUycOfUwM8vqX7KjR...|  3.0|Had a party of 6 ...|     0|59MxRhNVhU9MYndMk...|
# |ut6fi2W2YaipNOqvi...|   0|2014-11-12 14:12:20|    0|ZVvhc3Go7v5I8XTiV...|  3.0|Upland is a brewe...|     0|WBpQDAZymU0dhIqXc...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 5 rows

# %%
df_rdd.filter(df_rdd.stars > 2).show(3)
# Out:
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|   0|2018-07-07 22:09:11|    0|KU_O5udG6zpxOg-Vc...|  3.0|If you decide to ...|     0|mh_-eMZ6K5RLWhZyI...|
# |7ATYjTIgM3jUlt4UM...|   1|2012-01-03 15:28:18|    0|BiTunyQ73aT9WBnpR...|  5.0|I've taken a lot ...|     1|OyoGAe7OKpv6SyGZT...|
# |YjUWPpI6HXG530lwP...|   0|2014-02-05 20:30:30|    0|saUsX_uimxRlCVr67...|  3.0|Family diner. Had...|     0|8g_iMtfSiwikVnbP2...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 3 rows

# %%
df_rdd.filter("stars > 4 AND text LIKE '%amazing%'").show(5)
# Out:
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |7ATYjTIgM3jUlt4UM...|   1|2012-01-03 15:28:18|    0|BiTunyQ73aT9WBnpR...|  5.0|I've taken a lot ...|     1|OyoGAe7OKpv6SyGZT...|
# |LHSTtnW3YHCeUkRDG...|   0|2015-08-07 02:29:16|    0|_ZeMknuYdlQcUqng_...|  5.0|Amazingly amazing...|     2|yfFzsLmaWF2d4Sr0U...|
# |SZU9c8V2GuREDN5Kg...|   0|2016-05-31 02:14:54|    0|4zopEEPqfwm-c_FNp...|  5.0|We were a bit wea...|     0|JYYYKt6TdVA4ng9lL...|
# |EpREWeEpmR8f1qLHz...|   0|2011-11-30 06:58:36|    0|-up4mW6WdqzGrRh7t...|  5.0|After living in t...|     0|xbybLiQockAzC4xAl...|
# |5Ce3lZksYVkCbrihq...|   0|2014-07-25 17:56:26|    0|ymhbOMW63B_vGaRFR...|  5.0|I just started go...|     0|yZdAhQ_KmKuCZmbBy...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 5 rows

# %%
df_rdd.filter((df_rdd.stars > 4) & (df_rdd.text.like("%amazing%"))).show(5)
# Out:
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |7ATYjTIgM3jUlt4UM...|   1|2012-01-03 15:28:18|    0|BiTunyQ73aT9WBnpR...|  5.0|I've taken a lot ...|     1|OyoGAe7OKpv6SyGZT...|
# |LHSTtnW3YHCeUkRDG...|   0|2015-08-07 02:29:16|    0|_ZeMknuYdlQcUqng_...|  5.0|Amazingly amazing...|     2|yfFzsLmaWF2d4Sr0U...|
# |SZU9c8V2GuREDN5Kg...|   0|2016-05-31 02:14:54|    0|4zopEEPqfwm-c_FNp...|  5.0|We were a bit wea...|     0|JYYYKt6TdVA4ng9lL...|
# |EpREWeEpmR8f1qLHz...|   0|2011-11-30 06:58:36|    0|-up4mW6WdqzGrRh7t...|  5.0|After living in t...|     0|xbybLiQockAzC4xAl...|
# |5Ce3lZksYVkCbrihq...|   0|2014-07-25 17:56:26|    0|ymhbOMW63B_vGaRFR...|  5.0|I just started go...|     0|yZdAhQ_KmKuCZmbBy...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 5 rows

# %%
df_rdd.select(df_rdd.business_id, df_rdd.text.alias("review")).show(5)
# Out:
# +--------------------+--------------------+
# |         business_id|              review|
# +--------------------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|If you decide to ...|
# |7ATYjTIgM3jUlt4UM...|I've taken a lot ...|
# |YjUWPpI6HXG530lwP...|Family diner. Had...|
# |kxX2SOes4o-D3ZQBk...|Wow!  Yummy, diff...|
# |e4Vwtrqf-wpJfwesg...|Cute interior and...|
# +--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ---

# %% [markdown]
# ### Можно взять название колонок через строковую переменную. Это может быть удобно тогда, когда название столбца очень сложное!

# %%
import pyspark.sql.functions as f
df_rdd.select(df_rdd.business_id, f.col("text").alias("reviews")).show(5)
# Out:
# +--------------------+--------------------+
# |         business_id|             reviews|
# +--------------------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|If you decide to ...|
# |7ATYjTIgM3jUlt4UM...|I've taken a lot ...|
# |YjUWPpI6HXG530lwP...|Family diner. Had...|
# |kxX2SOes4o-D3ZQBk...|Wow!  Yummy, diff...|
# |e4Vwtrqf-wpJfwesg...|Cute interior and...|
# +--------------------+--------------------+
# only showing top 5 rows

# %%
# Если имя столбца хранится в переменной
column_name = "text"
df.select(df.business_id, f.col(column_name).alias("review")).show(10)
# Out:
# +--------------------+--------------------+
# |         business_id|              review|
# +--------------------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|If you decide to ...|
# |7ATYjTIgM3jUlt4UM...|I've taken a lot ...|
# |YjUWPpI6HXG530lwP...|Family diner. Had...|
# |kxX2SOes4o-D3ZQBk...|Wow!  Yummy, diff...|
# |e4Vwtrqf-wpJfwesg...|Cute interior and...|
# |04UD14gamNjLY0IDY...|I am a long term ...|
# |gmjsEdUsKpj9Xxu6p...|Loved this tour! ...|
# |LHSTtnW3YHCeUkRDG...|Amazingly amazing...|
# |B5XSoSG3SfvQGtKEG...|This easter inste...|
# |gebiRewfieSdtt17P...|Had a party of 6 ...|
# +--------------------+--------------------+
# only showing top 10 rows

# %%
# Если в имени столбца есть пробелы или специальные символы
#df.select(f.col("business id"), f.col("review text")).show()

# %%
# Удобно для последовательных преобразований
# df.select(
#     f.col("stars").cast("integer"),
#     f.col("text").substr(1, 100).alias("preview"),
#     f.upper(f.col("business_id")).alias("business_id_upper")
# ).show()

# %%
# Когда пишешь функцию, которая работает с любыми столбцами
# def analyze_column(df, column_name):
#     return df.select(
#         f.col(column_name),
#         f.length(f.col(column_name)).alias("length")
#     )

# analyze_column(df, "text").show()

# %%
# Если в DataFrame есть столбец с именем, совпадающим с методом DataFrame
# df.select(
#     f.col("count"),  # столбец "count", а не метод .count()
#     f.col("sum")     # столбец "sum", а не метод .sum()
# ).show()

# %% [markdown]
# ___

# %%
df_rdd[df_rdd.business_id, "text"].show(5)
# Out:
# +--------------------+--------------------+
# |         business_id|                text|
# +--------------------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|If you decide to ...|
# |7ATYjTIgM3jUlt4UM...|I've taken a lot ...|
# |YjUWPpI6HXG530lwP...|Family diner. Had...|
# |kxX2SOes4o-D3ZQBk...|Wow!  Yummy, diff...|
# |e4Vwtrqf-wpJfwesg...|Cute interior and...|
# +--------------------+--------------------+
# only showing top 5 rows

# %%
df_rdd["business_id", "text"].show(5)
# Out:
# +--------------------+--------------------+
# |         business_id|                text|
# +--------------------+--------------------+
# |XQfwVwDr-v0ZS3_Cb...|If you decide to ...|
# |7ATYjTIgM3jUlt4UM...|I've taken a lot ...|
# |YjUWPpI6HXG530lwP...|Family diner. Had...|
# |kxX2SOes4o-D3ZQBk...|Wow!  Yummy, diff...|
# |e4Vwtrqf-wpJfwesg...|Cute interior and...|
# +--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ---
# ### Полключим механизм SQL! Для этого нам необхолимо зарегистрировать таблицу

# %%
df_rdd.createOrReplaceTempView("df")

# %%
query_str = '''
SELECT COUNT(*) cnt, business_id
FROM df
GROUP BY business_id
'''

# %%
spark.sql(query_str).show(5)
# Out:
# [Stage 27:=====================================================>  (19 + 1) / 20]
# +---+--------------------+
# |cnt|         business_id|
# +---+--------------------+
# | 47|h_6ioAoKNLi01kPho...|
# | 53|2OEL_uLdTg90PiFVh...|
# |227|BnibjYoTYefJXQ_ZV...|
# | 94|L5rH_ypwqJcBByVac...|
# |508|P2XJbQZmf1zvWp9L_...|
# +---+--------------------+
# only showing top 5 rows

# %% [markdown]
# ___
# ## *Обхединение таблиц в HIVE*

# %%
business = spark.read.json("/data/yelp/business")
# Out:
# 25/12/08 16:10:05 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
business.show(2, vertical=True, truncate=False)
# Out:
# -RECORD 0--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  address      | 1616 Chapala St, Ste 2
#  attributes   | {null, null, null, null, null, null, null, null, null, null, null, True, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}
#  business_id  | Pns2l4eNsfO8kk83dixA6A
#  categories   | Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists
#  city         | Santa Barbara
#  hours        | null
#  is_open      | 0
#  latitude     | 34.4266787
#  longitude    | -119.7111968
#  name         | Abby Rappoport, LAC, CMQ
#  postal_code  | 93101
#  review_count | 7
#  stars        | 5.0
#  state        | CA
# -RECORD 1--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  address      | 87 Grasso Plaza Shopping Center
#  attributes   | {null, null, null, null, null, null, null, null, null, True, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}
#  business_id  | mpf3x-BjTdTEA3yCZrAYPw
#  categories   | Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services
#  city         | Affton
#  hours        | {8:0-18:30, 0:0-0:0, 8:0-14:0, null, 8:0-18:30, 8:0-18:30, 8:0-18:30}
#  is_open      | 1
#  latitude     | 38.551126
#  longitude    | -90.335695
#  name         | The UPS Store
#  postal_code  | 63123
#  review_count | 15
#  stars        | 3.0
#  state        | MO
# only showing top 2 rows

# %%
business.count()
# Out:
# 150346

# %%
df_rdd.show(2, vertical=True, truncate=False)
# Out:
# -RECORD 0------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | XQfwVwDr-v0ZS3_CbbE5Xw
#  cool        | 0
#  date        | 2018-07-07 22:09:11
#  funny       | 0
#  review_id   | KU_O5udG6zpxOg-VcAEodg
#  stars       | 3.0
#  text        | If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.
#  useful      | 0
#  user_id     | mh_-eMZ6K5RLWhZyISBhwA
# -RECORD 1------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id | 7ATYjTIgM3jUlt4UM3IypQ
#  cool        | 1
#  date        | 2012-01-03 15:28:18
#  funny       | 0
#  review_id   | BiTunyQ73aT9WBnpR9DZGw
#  stars       | 5.0
#  text        | I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do).\n\nThere is no way I can write this review without giving Russell, the owner of Body Cycle, a shout out. Russell's passion for fitness and cycling is so evident, as is his desire for all of his clients to succeed. He is always dropping in to classes to check in/provide encouragement, and is open to ideas and recommendations from anyone. Russell always wears a smile on his face, even when he's kicking your butt in class!
#  useful      | 1
#  user_id     | OyoGAe7OKpv6SyGZT5g77Q
# only showing top 2 rows

# %%
# %%time
business_review = df_rdd.join(business, on="business_id", how="inner")
# Out:
# CPU times: user 223 µs, sys: 4.08 ms, total: 4.3 ms
# Wall time: 48.2 ms

# %% [markdown]
# #### Посмотрим на план запроса

# %%
business_review.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [business_id#1854, cool#1855L, date#1856, funny#1857L, review_id#1858, stars#1859, text#1860, useful#1861L, user_id#1862, address#2244, attributes#2245, categories#2247, city#2248, hours#2249, is_open#2250L, latitude#2251, longitude#2252, name#2253, postal_code#2254, review_count#2255L, stars#2256, state#2257]
#    +- SortMergeJoin [business_id#1854], [business_id#2246], Inner
#       :- Sort [business_id#1854 ASC NULLS FIRST], false, 0
#       :  +- Exchange hashpartitioning(business_id#1854, 200), ENSURE_REQUIREMENTS, [plan_id=468]
#       :     +- Filter isnotnull(business_id#1854)
#       :        +- Scan ExistingRDD[business_id#1854,cool#1855L,date#1856,funny#1857L,review_id#1858,stars#1859,text#1860,useful#1861L,user_id#1862]
#       +- Sort [business_id#2246 ASC NULLS FIRST], false, 0
#          +- Exchange hashpartitioning(business_id#2246, 200), ENSURE_REQUIREMENTS, [plan_id=469]
#             +- Filter isnotnull(business_id#2246)
#                +- FileScan json [address#2244,attributes#2245,business_id#2246,categories#2247,city#2248,hours#2249,is_open#2250L,latitude#2251,longitude#2252,name#2253,postal_code#2254,review_count#2255L,stars#2256,state#2257] Batched: false, DataFilters: [isnotnull(business_id#2246)], Format: JSON, Location: InMemoryFileIndex(1 paths)[hdfs://master.hadoop.akhcheck.ru/data/yelp/business], PartitionFilters: [], PushedFilters: [IsNotNull(business_id)], ReadSchema: struct<address:string,attributes:struct<AcceptsInsurance:string,AgesAllowed:string,Alcohol:string...

# %%
business_review.show(2, vertical=True, truncate=False)
# Out:
# [Stage 41:==================================================>     (18 + 2) / 20]
# -RECORD 0-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id  | ---kPU91CF4Lq2-WlRu9Lw
#  cool         | 0
#  date         | 2021-11-25 02:49:38
#  funny        | 0
#  review_id    | 2HVxhnbaUfSfmC_RHjXLaQ
#  stars        | 5.0
#  text         | Hidden gem in NPR. Ordered the stone crabs, crab cakes, shrimp and fried lobster. Delicious! I highly recommend. The service is great, the food is awesome, bring your own drinks and let the good times roll.
#  useful       | 0
#  user_id      | lEPRGtvLLfJ2BQcU_w5UuA
#  address      | 4903 State Rd 54
#  attributes   | {null, null, u'none', {'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': False}, True, null, null, True, False, True, {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}, null, True, null, False, null, True, null, null, null, null, null, null, False, null, null, null, True, null, null, False, null, null, False, True, True, null, True, u'no'}
#  categories   | Seafood, Restaurants, Latin American, Food, Food Trucks
#  city         | New Port Richey
#  hours        | {11:0-22:0, 0:0-0:0, 11:0-22:0, null, 11:0-21:0, 11:0-21:0, 11:0-21:0}
#  is_open      | 1
#  latitude     | 28.2172884
#  longitude    | -82.7333444
#  name         | Frankie's Raw Bar
#  postal_code  | 34652
#  review_count | 24
#  stars        | 4.5
#  state        | FL
# -RECORD 1-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id  | ---kPU91CF4Lq2-WlRu9Lw
#  cool         | 0
#  date         | 2020-08-09 19:19:16
#  funny        | 0
#  review_id    | hoLKem4XpXGt_X4liqW9lw
#  stars        | 4.0
#  text         | Ate here for the 1st time on Saturday 08/07/2020. \nThe food was ok, had the Lobster Boil . The Lobster was ok for a soft shelled Lobster. The Crabs were soggy and mushy. The Clams were gummy and snotty . The headed shrimp were large and tasty. All the items were precooked, obviously. The fish spread was decent , also had the Fried Shrimp and Shrimp scampi  which were decent. BYOB ... ... The atmosphere was nice except for the zillion Flies. I'll be back with a six pack
#  useful       | 0
#  user_id      | 415SXXbQrl2-VudHa3ImbQ
#  address      | 4903 State Rd 54
#  attributes   | {null, null, u'none', {'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': False}, True, null, null, True, False, True, {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}, null, True, null, False, null, True, null, null, null, null, null, null, False, null, null, null, True, null, null, False, null, null, False, True, True, null, True, u'no'}
#  categories   | Seafood, Restaurants, Latin American, Food, Food Trucks
#  city         | New Port Richey
#  hours        | {11:0-22:0, 0:0-0:0, 11:0-22:0, null, 11:0-21:0, 11:0-21:0, 11:0-21:0}
#  is_open      | 1
#  latitude     | 28.2172884
#  longitude    | -82.7333444
#  name         | Frankie's Raw Bar
#  postal_code  | 34652
#  review_count | 24
#  stars        | 4.5
#  state        | FL
# only showing top 2 rows

# %% [markdown]
# Посмотрим на количество партиций в RDD. Под капотом Spark SQL использует RDD

# %%
business_review.rdd.getNumPartitions()
# Out:
# 67

# %% [markdown]
# ___
# #### Супермегабыстрый способ с броадкастом

# %% [markdown]
# Поменяем способ JOIN на BroadcastHashJoin

# %% [markdown]
# Дроп столбца

# %%
business.drop("stars")
# Out:
# DataFrame[address: string, attributes: struct<AcceptsInsurance:string,AgesAllowed:string,Alcohol:string,Ambience:string,BYOB:string,BYOBCorkage:string,BestNights:string,BikeParking:string,BusinessAcceptsBitcoin:string,BusinessAcceptsCreditCards:string,BusinessParking:string,ByAppointmentOnly:string,Caters:string,CoatCheck:string,Corkage:string,DietaryRestrictions:string,DogsAllowed:string,DriveThru:string,GoodForDancing:string,GoodForKids:string,GoodForMeal:string,HairSpecializesIn:string,HappyHour:string,HasTV:string,Music:string,NoiseLevel:string,Open24Hours:string,OutdoorSeating:string,RestaurantsAttire:string,RestaurantsCounterService:string,RestaurantsDelivery:string,RestaurantsGoodForGroups:string,RestaurantsPriceRange2:string,RestaurantsReservations:string,RestaurantsTableService:string,RestaurantsTakeOut:string,Smoking:string,WheelchairAccessible:string,WiFi:string>, business_id: string, categories: string, city: string, hours: struct<Friday:string,Monday:string,Saturday:string,Sunday:string,Thursday:string,Tuesday:string,Wednesday:string>, is_open: bigint, latitude: double, longitude: double, name: string, postal_code: string, review_count: bigint, state: string]

# %%
spark.sql("SET spark.sql.autoBroadcastJoinThreshold = 10")
business_review_new = df_rdd.join(f.broadcast(business.drop("stars")), on="business_id", how="inner")
business_review_new.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [business_id#1854, cool#1855L, date#1856, funny#1857L, review_id#1858, stars#1859, text#1860, useful#1861L, user_id#1862, address#2244, attributes#2245, categories#2247, city#2248, hours#2249, is_open#2250L, latitude#2251, longitude#2252, name#2253, postal_code#2254, review_count#2255L, state#2257]
#    +- BroadcastHashJoin [business_id#1854], [business_id#2246], Inner, BuildRight, false
#       :- Filter isnotnull(business_id#1854)
#       :  +- Scan ExistingRDD[business_id#1854,cool#1855L,date#1856,funny#1857L,review_id#1858,stars#1859,text#1860,useful#1861L,user_id#1862]
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[2, string, false]),false), [plan_id=702]
#          +- Filter isnotnull(business_id#2246)
#             +- FileScan json [address#2244,attributes#2245,business_id#2246,categories#2247,city#2248,hours#2249,is_open#2250L,latitude#2251,longitude#2252,name#2253,postal_code#2254,review_count#2255L,state#2257] Batched: false, DataFilters: [isnotnull(business_id#2246)], Format: JSON, Location: InMemoryFileIndex(1 paths)[hdfs://master.hadoop.akhcheck.ru/data/yelp/business], PartitionFilters: [], PushedFilters: [IsNotNull(business_id)], ReadSchema: struct<address:string,attributes:struct<AcceptsInsurance:string,AgesAllowed:string,Alcohol:string...

# %%
business_review_new.rdd.getNumPartitions()
# Out:
# 20

# %%
business_review_new.show(2, vertical=True, truncate=False)
# Out:
# [Stage 50:>                                                         (0 + 1) / 1]
# -RECORD 0-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id  | XQfwVwDr-v0ZS3_CbbE5Xw
#  cool         | 0
#  date         | 2018-07-07 22:09:11
#  funny        | 0
#  review_id    | KU_O5udG6zpxOg-VcAEodg
#  stars        | 3.0
#  text         | If you decide to eat here, just be aware it is going to take about 2 hours from beginning to end. We have tried it multiple times, because I want to like it! I have been to it's other locations in NJ and never had a bad experience. \n\nThe food is good, but it takes a very long time to come out. The waitstaff is very young, but usually pleasant. We have just had too many experiences where we spent way too long waiting. We usually opt for another diner or restaurant on the weekends, in order to be done quicker.
#  useful       | 0
#  user_id      | mh_-eMZ6K5RLWhZyISBhwA
#  address      | 1460 Bethlehem Pike
#  attributes   | {null, null, 'none', {'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': True}, null, null, null, False, False, True, {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}, null, False, null, null, null, False, null, null, True, {'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}, null, False, False, null, u'average', null, True, 'casual', null, True, True, 2, False, True, True, null, True, 'free'}
#  categories   | Restaurants, Breakfast & Brunch, Food, Juice Bars & Smoothies, American (New), Coffee & Tea, Sandwiches
#  city         | North Wales
#  hours        | {7:30-15:0, 7:30-15:0, 7:30-15:0, 7:30-15:0, 7:30-15:0, 7:30-15:0, 7:30-15:0}
#  is_open      | 1
#  latitude     | 40.2101961875
#  longitude    | -75.2236385919
#  name         | Turning Point of North Wales
#  postal_code  | 19454
#  review_count | 169
#  state        | PA
# -RECORD 1-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  business_id  | 7ATYjTIgM3jUlt4UM3IypQ
#  cool         | 1
#  date         | 2012-01-03 15:28:18
#  funny        | 0
#  review_id    | BiTunyQ73aT9WBnpR9DZGw
#  stars        | 5.0
#  text         | I've taken a lot of spin classes over the years, and nothing compares to the classes at Body Cycle. From the nice, clean space and amazing bikes, to the welcoming and motivating instructors, every class is a top notch work out.\n\nFor anyone who struggles to fit workouts in, the online scheduling system makes it easy to plan ahead (and there's no need to line up way in advanced like many gyms make you do).\n\nThere is no way I can write this review without giving Russell, the owner of Body Cycle, a shout out. Russell's passion for fitness and cycling is so evident, as is his desire for all of his clients to succeed. He is always dropping in to classes to check in/provide encouragement, and is open to ideas and recommendations from anyone. Russell always wears a smile on his face, even when he's kicking your butt in class!
#  useful       | 1
#  user_id      | OyoGAe7OKpv6SyGZT5g77Q
#  address      | 1923 Chestnut St, 2nd Fl
#  attributes   | {null, null, null, null, null, null, null, True, null, True, {'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}, False, null, null, null, null, null, null, null, False, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null}
#  categories   | Active Life, Cycling Classes, Trainers, Gyms, Fitness & Instruction
#  city         | Philadelphia
#  hours        | {6:0-19:30, 6:30-20:30, 7:30-12:30, 9:0-13:0, 6:30-20:30, 6:30-20:30, 6:0-20:30}
#  is_open      | 0
#  latitude     | 39.9521029
#  longitude    | -75.1727526
#  name         | Body Cycle Spinning Studio
#  postal_code  | 19119
#  review_count | 144
#  state        | PA
# only showing top 2 rows

# %% [markdown]
# #### Посчитаем статистики

# %%
business_review_new.groupby("business_id").agg(f.avg("stars")).show(5)
# Out:
# [Stage 52:=====================================================>  (19 + 1) / 20]
# +--------------------+------------------+
# |         business_id|        avg(stars)|
# +--------------------+------------------+
# |WKMJwqnfZKsAae75R...|             3.825|
# |sk2lZI4zmuGAccd3D...| 4.757575757575758|
# |zJErbOQMKX-MwHs_u...|2.9279279279279278|
# |NQhyMw8SOU1HB-V9X...|              2.62|
# |neL2xrin-uMJl5ABK...| 3.611111111111111|
# +--------------------+------------------+
# only showing top 5 rows

# %% [markdown]
# Посчитаем количество review по разным регионам

# %%
business_review_new.groupby('state').count().distinct().show(5)
# Out:
# [Stage 56:=====================================================>  (19 + 1) / 20]
# +-----+------+
# |state| count|
# +-----+------+
# |   AZ|431708|
# |   LA|761673|
# |   NJ|260897|
# |   NV|430678|
# |   ID|157572|
# +-----+------+
# only showing top 5 rows

# %%
result = business_review_new.groupby('city').count().distinct()

# %%
result.show(10)
# Out:
# [Stage 60:=====================================================>  (19 + 1) / 20]
# +------------------+-----+
# |              city|count|
# +------------------+-----+
# |      Harleysville| 2640|
# |       Merion Park|    7|
# |        Westampton|  822|
# |       Springfield|11686|
# |         Frontenac| 1560|
# |       Marcus Hook|  500|
# |     Pleasant View|  822|
# |           Truckee|  198|
# |   King Of Prussia| 8470|
# |Indian Rocks Beach|10639|
# +------------------+-----+
# only showing top 10 rows

# %% [markdown]
# Запишем результаты в таблицу

# %%
result.write.csv("business_review_counts.tsv", sep='\t', mode='overwrite')

# %% [markdown]
# Посмотрим содержимое записей

# %%
df_check = spark.read.csv("business_review_counts.tsv", sep='\t')
df_check.show(5)
# Out:
# +------------+-----+
# |         _c0|  _c1|
# +------------+-----+
# |Harleysville| 2640|
# | Merion Park|    7|
# |  Westampton|  822|
# | Springfield|11686|
# |   Frontenac| 1560|
# +------------+-----+
# only showing top 5 rows

# %% [markdown]
# ---
# ### Оконные функции

# %%
# Приобразование запроса вида:
SELECT business_id, user_id, useful
LEAD(useful) OVER (PARTITION BY business_id ORDER BY useful DESC),
RANK() OVER (PARTITION BY business_id ORDER BY useful DESC)
LIMIT 10;

# %%
from pyspark.sql import Window

# Создаем оконную спецификацию один раз
window_spec = Window.partitionBy("business_id").orderBy(f.col("useful").desc())

df.select(
    "business_id", 
    "user_id", 
    "useful",
    f.rank().over(window_spec).alias("rank"),  # Ранжирование
    f.lead("useful").over(window_spec).alias("next_useful")  # Следующее значение
).show(5)
# Out:
# [Stage 82:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+------+----+-----------+
# |         business_id|             user_id|useful|rank|next_useful|
# +--------------------+--------------------+------+----+-----------+
# |---kPU91CF4Lq2-Wl...|i48cHEyRBl5g9_npY...|     4|   1|          3|
# |---kPU91CF4Lq2-Wl...|Q-ia5eY9smWBTwYOZ...|     3|   2|          2|
# |---kPU91CF4Lq2-Wl...|qrCkKrEwQ-q9m1iWS...|     2|   3|          1|
# |---kPU91CF4Lq2-Wl...|V8oYXtc0hMuYzG5Hf...|     1|   4|          1|
# |---kPU91CF4Lq2-Wl...|UmQDlaIjLiPBZ7M6U...|     1|   4|          1|
# +--------------------+--------------------+------+----+-----------+
# only showing top 5 rows

# %%
# С использованием where
df.select(
    "business_id", 
    "user_id", 
    "useful",
    f.rank().over(window_spec).alias("rank"),  # Ранжирование
    f.lead("useful").over(window_spec).alias("next_useful")  # Следующее значение
).where("rank <= 3").show(5)
# Out:
# [Stage 85:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+------+----+-----------+
# |         business_id|             user_id|useful|rank|next_useful|
# +--------------------+--------------------+------+----+-----------+
# |---kPU91CF4Lq2-Wl...|i48cHEyRBl5g9_npY...|     4|   1|          3|
# |---kPU91CF4Lq2-Wl...|Q-ia5eY9smWBTwYOZ...|     3|   2|          2|
# |---kPU91CF4Lq2-Wl...|qrCkKrEwQ-q9m1iWS...|     2|   3|          1|
# |--9osgUCSDUWUkoTL...|g2eQ3vyzupM3WdtXl...|     6|   1|          3|
# |--9osgUCSDUWUkoTL...|iZPO_Rd5BU-Y72KKi...|     3|   2|          2|
# +--------------------+--------------------+------+----+-----------+
# only showing top 5 rows

# %% [markdown]
# ### Итоги
# 1. Spark SQL использует обертку в виде SparkSession
# 2. Spark автоматически подхватывает схему в случае JSON, в случае чтения CSV-данных необходимо указывать схему данных.
# 3. Broadcast — аналог Distributed Cache.
# 4. Можно писать запросы в SQL в Spark
# 5. Можно оптимизировать Join через BroadcastHashJoin
