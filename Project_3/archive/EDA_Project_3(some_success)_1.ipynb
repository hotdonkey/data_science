# %%
import pandas as pd
import numpy as np
import re
import requests
import seaborn as sns

# %%
hotels = pd.read_csv('./data/hotels.csv')
hotels.head(3)
# Out:
#                                        hotel_address  \
# 0  Stratton Street Mayfair Westminster Borough Lo...
# 1  130 134 Southampton Row Camden London WC1B 5AF...
# 2   151 bis Rue de Rennes 6th arr 75006 Paris France
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           581   2/19/2016            8.4
# 1                           299   1/12/2017            8.3
# 2                            32  10/18/2016            8.9
#
#                           hotel_name reviewer_nationality  \
# 0                 The May Fair Hotel      United Kingdom
# 1    Mercure London Bloomsbury Hotel      United Kingdom
# 2  Legend Saint Germain by Elegancia               China
#
#        negative_review  review_total_negative_word_counts  \
# 0             Leaving                                   3
# 1       poor breakfast                                  3
# 2   No kettle in room                                   6
#
#    total_number_of_reviews      positive_review  \
# 0                     1994   Staff were amazing
# 1                     1361             location
# 2                      406          No Positive
#
#    review_total_positive_word_counts  \
# 0                                  4
# 1                                  2
# 2                                  0
#
#    total_number_of_reviews_reviewer_has_given  reviewer_score  \
# 0                                           7            10.0
# 1                                          14             6.3
# 2                                          14             7.5
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Studio Suite ...           531 day
# 1  [' Business trip ', ' Couple ', ' Standard Dou...           203 day
# 2  [' Leisure trip ', ' Solo traveler ', ' Modern...           289 day
#
#          lat       lng
# 0  51.507894 -0.143671
# 1  51.521009 -0.123097
# 2  48.845377  2.325643

# %%
#Заполняем пропуски
hotels = hotels.fillna(0)

# %%
#Удаляем дубликаты 
hotels = hotels.drop_duplicates()

# %% [markdown]
# ---

# %% [markdown]
# Преобразование тегов

# %%
# Пркобразование тегов к списку
def tag_reconstr(data):
    temp_list = []
    for i in data.split("'"):
        temp_list.append(i.strip())

    temp_list.remove('[')
    temp_list.remove(']')

    for i in temp_list:
        if i == ',':
            temp_list.remove(i)
    return temp_list


tags_series = hotels['tags'].apply(tag_reconstr)
hotels['tags'] = hotels['tags'].apply(tag_reconstr)

#Формируем базу для one_hot, параллельно выдергиваем фит прожитых ночей
all_tags = tags_series.explode()
stayed_night_mask = all_tags.str.contains('Stayed', regex=False)
stayed_night = all_tags[stayed_night_mask]
stayed_night.str.split(' ')

def night_at_hotel(data):
    temp_var = 0
    for i in data.split(' '):
        try:
            temp_var = int(i)
        except ValueError:
            pass
    return temp_var

nights = stayed_night.apply(night_at_hotel)
nights = nights.rename('nights')
hotels = pd.concat([hotels, nights], axis=1)
hotels['nights'] = hotels['nights'].fillna(hotels['nights'].mode()[0])

#Вытаскиваем топ 10 тегов и разворачиваем на их основе one_hot
top_tags = all_tags.value_counts()[:11]
mask = top_tags.index.str.contains('Stayed', regex=False)
one_hot_columns = list(top_tags[~mask].index)

for element in one_hot_columns:
    hotels[element] = hotels['tags'].apply(lambda x: 1 if element in x else 0)

# %% [markdown]
# Кодируем отели (вносит шум)

# %%
#Кодируем названия отелей
hotels['hotel_name'] = hotels['hotel_name'].astype('category')
hotels['hotel_name'] = hotels['hotel_name'].cat.codes

# %% [markdown]
# Проверяем на мультиколлинеарность

# %%
hotels.corr()[(hotels.corr() > 0.7) | (hotels.corr() < -0.7)]
# Out:
# /var/folders/1_/hgb3xg852md0hqqs3ybwbsp40000gn/T/ipykernel_21425/3602652802.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hotels.corr()[(hotels.corr() > 0.7) | (hotels.corr() < -0.7)]
#                                             additional_number_of_scoring  \
# additional_number_of_scoring                                    1.000000
# average_score                                                        NaN
# hotel_name                                                           NaN
# review_total_negative_word_counts                                    NaN
# total_number_of_reviews                                         0.824494
# review_total_positive_word_counts                                    NaN
# total_number_of_reviews_reviewer_has_given                           NaN
# reviewer_score                                                       NaN
# lat                                                                  NaN
# lng                                                                  NaN
# nights                                                               NaN
# Leisure trip                                                         NaN
# Submitted from a mobile device                                       NaN
# Couple                                                               NaN
# Solo traveler                                                        NaN
# Business trip                                                        NaN
# Group                                                                NaN
# Family with young children                                           NaN
#
#                                             average_score  hotel_name  \
# additional_number_of_scoring                          NaN         NaN
# average_score                                         1.0         NaN
# hotel_name                                            NaN         1.0
# review_total_negative_word_counts                     NaN         NaN
# total_number_of_reviews                               NaN         NaN
# review_total_positive_word_counts                     NaN         NaN
# total_number_of_reviews_reviewer_has_given            NaN         NaN
# reviewer_score                                        NaN         NaN
# lat                                                   NaN         NaN
# lng                                                   NaN         NaN
# nights                                                NaN         NaN
# Leisure trip                                          NaN         NaN
# Submitted from a mobile device                        NaN         NaN
# Couple                                                NaN         NaN
# Solo traveler                                         NaN         NaN
# Business trip                                         NaN         NaN
# Group                                                 NaN         NaN
# Family with young children                            NaN         NaN
#
#                                             review_total_negative_word_counts  \
# additional_number_of_scoring                                              NaN
# average_score                                                             NaN
# hotel_name                                                                NaN
# review_total_negative_word_counts                                         1.0
# total_number_of_reviews                                                   NaN
# review_total_positive_word_counts                                         NaN
# total_number_of_reviews_reviewer_has_given                                NaN
# reviewer_score                                                            NaN
# lat                                                                       NaN
# lng                                                                       NaN
# nights                                                                    NaN
# Leisure trip                                                              NaN
# Submitted from a mobile device                                            NaN
# Couple                                                                    NaN
# Solo traveler                                                             NaN
# Business trip                                                             NaN
# Group                                                                     NaN
# Family with young children                                                NaN
#
#                                             total_number_of_reviews  \
# additional_number_of_scoring                               0.824494
# average_score                                                   NaN
# hotel_name                                                      NaN
# review_total_negative_word_counts                               NaN
# total_number_of_reviews                                    1.000000
# review_total_positive_word_counts                               NaN
# total_number_of_reviews_reviewer_has_given                      NaN
# reviewer_score                                                  NaN
# lat                                                             NaN
# lng                                                             NaN
# nights                                                          NaN
# Leisure trip                                                    NaN
# Submitted from a mobile device                                  NaN
# Couple                                                          NaN
# Solo traveler                                                   NaN
# Business trip                                                   NaN
# Group                                                           NaN
# Family with young children                                      NaN
#
#                                             review_total_positive_word_counts  \
# additional_number_of_scoring                                              NaN
# average_score                                                             NaN
# hotel_name                                                                NaN
# review_total_negative_word_counts                                         NaN
# total_number_of_reviews                                                   NaN
# review_total_positive_word_counts                                         1.0
# total_number_of_reviews_reviewer_has_given                                NaN
# reviewer_score                                                            NaN
# lat                                                                       NaN
# lng                                                                       NaN
# nights                                                                    NaN
# Leisure trip                                                              NaN
# Submitted from a mobile device                                            NaN
# Couple                                                                    NaN
# Solo traveler                                                             NaN
# Business trip                                                             NaN
# Group                                                                     NaN
# Family with young children                                                NaN
#
#                                             total_number_of_reviews_reviewer_has_given  \
# additional_number_of_scoring                                                       NaN
# average_score                                                                      NaN
# hotel_name                                                                         NaN
# review_total_negative_word_counts                                                  NaN
# total_number_of_reviews                                                            NaN
# review_total_positive_word_counts                                                  NaN
# total_number_of_reviews_reviewer_has_given                                         1.0
# reviewer_score                                                                     NaN
# lat                                                                                NaN
# lng                                                                                NaN
# nights                                                                             NaN
# Leisure trip                                                                       NaN
# Submitted from a mobile device                                                     NaN
# Couple                                                                             NaN
# Solo traveler                                                                      NaN
# Business trip                                                                      NaN
# Group                                                                              NaN
# Family with young children                                                         NaN
#
#                                             reviewer_score  lat  lng  nights  \
# additional_number_of_scoring                           NaN  NaN  NaN     NaN
# average_score                                          NaN  NaN  NaN     NaN
# hotel_name                                             NaN  NaN  NaN     NaN
# review_total_negative_word_counts                      NaN  NaN  NaN     NaN
# total_number_of_reviews                                NaN  NaN  NaN     NaN
# review_total_positive_word_counts                      NaN  NaN  NaN     NaN
# total_number_of_reviews_reviewer_has_given             NaN  NaN  NaN     NaN
# reviewer_score                                         1.0  NaN  NaN     NaN
# lat                                                    NaN  1.0  NaN     NaN
# lng                                                    NaN  NaN  1.0     NaN
# nights                                                 NaN  NaN  NaN     1.0
# Leisure trip                                           NaN  NaN  NaN     NaN
# Submitted from a mobile device                         NaN  NaN  NaN     NaN
# Couple                                                 NaN  NaN  NaN     NaN
# Solo traveler                                          NaN  NaN  NaN     NaN
# Business trip                                          NaN  NaN  NaN     NaN
# Group                                                  NaN  NaN  NaN     NaN
# Family with young children                             NaN  NaN  NaN     NaN
#
#                                             Leisure trip  \
# additional_number_of_scoring                         NaN
# average_score                                        NaN
# hotel_name                                           NaN
# review_total_negative_word_counts                    NaN
# total_number_of_reviews                              NaN
# review_total_positive_word_counts                    NaN
# total_number_of_reviews_reviewer_has_given           NaN
# reviewer_score                                       NaN
# lat                                                  NaN
# lng                                                  NaN
# nights                                               NaN
# Leisure trip                                    1.000000
# Submitted from a mobile device                       NaN
# Couple                                               NaN
# Solo traveler                                        NaN
# Business trip                                  -0.904162
# Group                                                NaN
# Family with young children                           NaN
#
#                                             Submitted from a mobile device  \
# additional_number_of_scoring                                           NaN
# average_score                                                          NaN
# hotel_name                                                             NaN
# review_total_negative_word_counts                                      NaN
# total_number_of_reviews                                                NaN
# review_total_positive_word_counts                                      NaN
# total_number_of_reviews_reviewer_has_given                             NaN
# reviewer_score                                                         NaN
# lat                                                                    NaN
# lng                                                                    NaN
# nights                                                                 NaN
# Leisure trip                                                           NaN
# Submitted from a mobile device                                         1.0
# Couple                                                                 NaN
# Solo traveler                                                          NaN
# Business trip                                                          NaN
# Group                                                                  NaN
# Family with young children                                             NaN
#
#                                             Couple  Solo traveler  \
# additional_number_of_scoring                   NaN            NaN
# average_score                                  NaN            NaN
# hotel_name                                     NaN            NaN
# review_total_negative_word_counts              NaN            NaN
# total_number_of_reviews                        NaN            NaN
# review_total_positive_word_counts              NaN            NaN
# total_number_of_reviews_reviewer_has_given     NaN            NaN
# reviewer_score                                 NaN            NaN
# lat                                            NaN            NaN
# lng                                            NaN            NaN
# nights                                         NaN            NaN
# Leisure trip                                   NaN            NaN
# Submitted from a mobile device                 NaN            NaN
# Couple                                         1.0            NaN
# Solo traveler                                  NaN            1.0
# Business trip                                  NaN            NaN
# Group                                          NaN            NaN
# Family with young children                     NaN            NaN
#
#                                             Business trip  Group  \
# additional_number_of_scoring                          NaN    NaN
# average_score                                         NaN    NaN
# hotel_name                                            NaN    NaN
# review_total_negative_word_counts                     NaN    NaN
# total_number_of_reviews                               NaN    NaN
# review_total_positive_word_counts                     NaN    NaN
# total_number_of_reviews_reviewer_has_given            NaN    NaN
# reviewer_score                                        NaN    NaN
# lat                                                   NaN    NaN
# lng                                                   NaN    NaN
# nights                                                NaN    NaN
# Leisure trip                                    -0.904162    NaN
# Submitted from a mobile device                        NaN    NaN
# Couple                                                NaN    NaN
# Solo traveler                                         NaN    NaN
# Business trip                                    1.000000    NaN
# Group                                                 NaN    1.0
# Family with young children                            NaN    NaN
#
#                                             Family with young children
# additional_number_of_scoring                                       NaN
# average_score                                                      NaN
# hotel_name                                                         NaN
# review_total_negative_word_counts                                  NaN
# total_number_of_reviews                                            NaN
# review_total_positive_word_counts                                  NaN
# total_number_of_reviews_reviewer_has_given                         NaN
# reviewer_score                                                     NaN
# lat                                                                NaN
# lng                                                                NaN
# nights                                                             NaN
# Leisure trip                                                       NaN
# Submitted from a mobile device                                     NaN
# Couple                                                             NaN
# Solo traveler                                                      NaN
# Business trip                                                      NaN
# Group                                                              NaN
# Family with young children                                         1.0

# %%
hotels.drop(['additional_number_of_scoring', 'Business trip'], axis=1, inplace=True)

# %% [markdown]
# ---

# %%
#Дропаем строковые фиты
object_columns = [s for s in hotels.columns if hotels[s].dtypes == 'object']
hotels.drop(object_columns, axis = 1, inplace=True)

# %%
# Разбиваем датафрейм на части, необходимые для обучения и тестирования модели  
# Х - данные с информацией об отелях, у - целевая переменная (рейтинги отелей)  
X = hotels.drop(['reviewer_score'], axis = 1)  
y = hotels['reviewer_score']

# %%
# Загружаем специальный инструмент для разбивки:  
from sklearn.model_selection import train_test_split

# %%
# Наборы данных с меткой "train" будут использоваться для обучения модели, "test" - для тестирования.  
# Для тестирования мы будем использовать 25% от исходного датасета.  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Импортируем необходимые библиотеки:  
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели  
from sklearn import metrics # инструменты для оценки точности модели  
  
# Создаём модель  
regr = RandomForestRegressor(n_estimators=100)  
      
# Обучаем модель на тестовом наборе данных  
regr.fit(X_train, y_train)  
      
# Используем обученную модель для предсказания рейтинга отелей в тестовой выборке.  
# Предсказанные значения записываем в переменную y_pred  
y_pred = regr.predict(X_test)

# %%
# Сравниваем предсказанные значения (y_pred) с реальными (y_test), и смотрим насколько они отличаются  
# Метрика называется Mean Absolute Percentage Error (MAPE) и показывает среднюю абсолютную процентную ошибку предсказанных значений от фактических.  
print('MAPE:', metrics.mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MAPE: 0.13799049916442563
