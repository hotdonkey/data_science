# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.lme.com/Metals/Non-ferrous#tabIndex=1'
response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
page = BeautifulSoup(response.text, 'html.parser')

print(page.find('div', class_='metal-block-row__blocks'))
# Out:
# <div class="metal-block-row__blocks" ref="row">
# <metal-block :data="getIndividualBlockData('1b72897c-6a30-480c-a74a-cfc2faaaff16')" data-block-id="1b72897c-6a30-480c-a74a-cfc2faaaff16" data-day-delayed="True" id="1b72897c-6a30-480c-a74a-cfc2faaaff16" inline-template="" is-day-delayed="is-day-delayed" ref="block-1b72897c-6a30-480c-a74a-cfc2faaaff16">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-Aluminium" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME Aluminium
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# <metal-block :data="getIndividualBlockData('fc09fcde-6438-4834-9221-98da9ed54eea')" data-block-id="fc09fcde-6438-4834-9221-98da9ed54eea" data-day-delayed="True" id="fc09fcde-6438-4834-9221-98da9ed54eea" inline-template="" is-day-delayed="is-day-delayed" ref="block-fc09fcde-6438-4834-9221-98da9ed54eea">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-Copper" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME Copper
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# <metal-block :data="getIndividualBlockData('b411edcc-fc99-4da8-ba18-da82b8a5dad4')" data-block-id="b411edcc-fc99-4da8-ba18-da82b8a5dad4" data-day-delayed="True" id="b411edcc-fc99-4da8-ba18-da82b8a5dad4" inline-template="" is-day-delayed="is-day-delayed" ref="block-b411edcc-fc99-4da8-ba18-da82b8a5dad4">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-Zinc" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME Zinc
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# <metal-block :data="getIndividualBlockData('6326cb5f-0770-4ba6-a3b4-871ecf0566f7')" data-block-id="6326cb5f-0770-4ba6-a3b4-871ecf0566f7" data-day-delayed="True" id="6326cb5f-0770-4ba6-a3b4-871ecf0566f7" inline-template="" is-day-delayed="is-day-delayed" ref="block-6326cb5f-0770-4ba6-a3b4-871ecf0566f7">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-Nickel" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME Nickel
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# <metal-block :data="getIndividualBlockData('14f25c1d-fd36-459d-a228-e088180bfb75')" data-block-id="14f25c1d-fd36-459d-a228-e088180bfb75" data-day-delayed="True" id="14f25c1d-fd36-459d-a228-e088180bfb75" inline-template="" is-day-delayed="is-day-delayed" ref="block-14f25c1d-fd36-459d-a228-e088180bfb75">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-Lead" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME Lead
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# <metal-block :data="getIndividualBlockData('1dcd0785-8af8-4df3-aae0-084e9a686654')" data-block-id="1dcd0785-8af8-4df3-aae0-084e9a686654" data-day-delayed="True" id="1dcd0785-8af8-4df3-aae0-084e9a686654" inline-template="" is-day-delayed="is-day-delayed" ref="block-1dcd0785-8af8-4df3-aae0-084e9a686654">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-Tin" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME Tin
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# <metal-block :data="getIndividualBlockData('4b9fe162-6e23-4566-ba72-6f798c10c605')" data-block-id="4b9fe162-6e23-4566-ba72-6f798c10c605" data-day-delayed="True" id="4b9fe162-6e23-4566-ba72-6f798c10c605" inline-template="" is-day-delayed="is-day-delayed" ref="block-4b9fe162-6e23-4566-ba72-6f798c10c605">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-Aluminium-Alloy" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME Aluminium Alloy
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# <metal-block :data="getIndividualBlockData('e7c48262-7026-401e-8e12-3311783bf629')" data-block-id="e7c48262-7026-401e-8e12-3311783bf629" data-day-delayed="True" id="e7c48262-7026-401e-8e12-3311783bf629" inline-template="" is-day-delayed="is-day-delayed" ref="block-e7c48262-7026-401e-8e12-3311783bf629">
# <a :class="{
#           'metal-block--init': isInit,
#           'metal-block--refreshed': blockUpdated
#         }" class="metal-block" href="/en/Metals/Non-ferrous/LME-NASAAC" v-on:animationend="blockUpdated = false">
# <div class="metal-block__inner">
# <h4 class="metal-block__title">
# <span class="metal-block__title-text">
#                     LME NASAAC
#                 </span>
# </h4>
# <span class="metal-block__price-wrapper">
# <span class="metal-block__price">{{ price }}</span>
# </span>
# <span class="metal-block__change-wrapper">
# <span :class="{
#                 'metal-block__change--up': changeDirection === 'up',
#                 'metal-block__change--down': changeDirection === 'down'
#               }" class="metal-block__change">
#                     {{ change }}
#                 </span>
# </span>
# <span class="metal-block__type">Official Price</span>
# </div>
# </a>
# </metal-block>
# </div>
