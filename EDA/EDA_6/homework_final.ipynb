# %%
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
from comet_ml import Experiment

# %%
df = pd.read_csv('../data/KaggleV2-May-2016.csv')

# %%
df_exclude = df.drop(['PatientId', 'AppointmentID'],axis=1)

# %%
experiment = Experiment(
    api_key='WAXoelkf8lkxGt9Up0VQ7L4Nn',
    project_name='medical-appointment',
    workspace='hotdonkey',
)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/hotdonkey/medical-appointment/0d3dae4090fc4b7bb009290dbac502e5

# %%
sns.heatmap(df_exclude.corr(),annot=True)
experiment.log_figure(figure=plt)
# Out:
# /var/folders/18/xwlc5znx4tz1pcrtznkl3fch0000gn/T/ipykernel_25702/1933604936.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_exclude.corr(),annot=True)
# {'web': 'https://www.comet.com/api/image/download?imageId=48285a74c7e84b0a8054c1444e6fabf2&experimentKey=0d3dae4090fc4b7bb009290dbac502e5',
#  'api': 'https://www.comet.com/api/rest/v1/image/get-image?imageId=48285a74c7e84b0a8054c1444e6fabf2&experimentKey=0d3dae4090fc4b7bb009290dbac502e5',
#  'imageId': '48285a74c7e84b0a8054c1444e6fabf2'}

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.com/hotdonkey/medical-appointment/0d3dae4090fc4b7bb009290dbac502e5
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     figures                  : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (218.41 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading 1 metrics, params and output messages
# COMET INFO: Waiting for completion of the file uploads (may take several seconds)
# COMET INFO: The Python SDK has 10800 seconds to finish before aborting...
# COMET INFO: All files uploaded, waiting for confirmation they have been all received
